# %% [markdown]
# # MLFLOW EXPERIMENT TRACKING

# %% [markdown]
# ## SET UP ENVIRONMENT

# %% [markdown]
# ## Scenario 3: Multiple data scientists working on multiple ML models
#
# MLflow setup:
# * Tracking server: yes, remote server (EC2).
# * Backend store: postgresql database.
# * Artifacts store: s3 bucket.
#
# The experiments can be explored by accessing the remote server.
#
# The exampe uses AWS to host a remote server. In order to run the example you'll need an AWS account. Follow the steps described in the file `mlflow_on_aws.md` to create a new AWS account and launch the tracking server.

# %%
import pandas as pd
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## SET UP MLFLOW

# %%
import os

os.environ["AWS_PROFILE"] = "" # fill in with your AWS profile. More info: https://docs.aws.amazon.com/sdk-for-java/latest/developer-guide/setup.html#setup-credentials

TRACKING_SERVER_HOST = "" # fill in with the public DNS of the EC2 instance
mlflow.set_tracking_uri(f"http://{TRACKING_SERVER_HOST}:5000")
# Out:
# [2022-06-18 21:37:45 +0700] [47213] [INFO] Starting gunicorn 20.1.0
# [2022-06-18 21:37:45 +0700] [47213] [INFO] Listening at: http://127.0.0.1:5000 (47213)
# [2022-06-18 21:37:45 +0700] [47213] [INFO] Using worker: sync
# [2022-06-18 21:37:45 +0700] [47218] [INFO] Booting worker with pid: 47218
# [2022-06-18 21:38:23 +0700] [47213] [INFO] Handling signal: int
# Error while terminating subprocess (pid=47207):
# [2022-06-18 21:38:23 +0700] [47218] [INFO] Worker exiting (pid: 47218)
#
# Aborted!
# [2022-06-18 21:38:23 +0700] [47213] [INFO] Shutting down: Master

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("taxi_trip_prediction-experiment")
# Out:
# 2022/07/09 20:56:56 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2022/07/09 20:56:56 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade  -> 451aebb31d03, add metric step
# INFO  [alembic.runtime.migration] Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# INFO  [alembic.runtime.migration] Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# INFO  [alembic.runtime.migration] Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# INFO  [alembic.runtime.migration] Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# INFO  [alembic.runtime.migration] Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# INFO  [89d4b8295536_create_latest_metrics_table_py] Migration complete!
# INFO  [alembic.runtime.migration] Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# INFO  [2b4d017a5e9b_add_model_registry_tables_to_db_py] Adding registered_models and model_versions tables to database.
# INFO  [2b4d017a5e9b_add_model_registry_tables_to_db_py] Migration complete!
# INFO  [alembic.runtime.migration] Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# INFO  [alembic.runtime.migration] Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# INFO  [alembic.runtime.migration] Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# INFO  [alembic.runtime.migration] Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# INFO  [alembic.runtime.migration] Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# INFO  [alembic.runtime.migration] Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# INFO  [alembic.runtime.migration] Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# INFO  [alembic.runtime.migration] Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# INFO  [alembic.runtime.migration] Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2022/07/09 20:56:56 INFO mlflow.tracking.fluent: Experiment with name 'taxi_trip_prediction-experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='./mlruns/1', experiment_id='1', lifecycle_stage='active', name='taxi_trip_prediction-experiment', tags={}>

# %% [markdown]
# ## PREPARE DATASET

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df['lpep_dropoff_datetime'] = pd.to_datetime(df['lpep_dropoff_datetime'])
    df['lpep_pickup_datetime'] = pd.to_datetime(df['lpep_pickup_datetime'])

    df['duration'] = df['lpep_dropoff_datetime'] - df['lpep_pickup_datetime']
    df['duration'] = df['duration'].apply(lambda x: x.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
train_path = './data/green_tripdata_2021-01.parquet'
valid_path = './data/green_tripdata_2021-02.parquet'

# %%
df_train = read_dataframe(train_path)
df_val = read_dataframe(valid_path)

# %%
print(f'train_dataset: {len(df_train)}')
print(f'valid_dataset: {len(df_val)}')
# Out:
# train_dataset: 73908
# valid_dataset: 61921

# %% [markdown]
# ## FEATURE ENGINEERING

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
from pathlib import Path

model_path = Path('./mlflow/models/')
model_path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## MODEL TRAINING AND EXPERIMENT

# %% [markdown]
# ### LINEAR REGRESSION - BASELINE

# %%
with mlflow.start_run(run_name="base_model"):
    
    mlflow.set_tag("developer", "surawut")
    mlflow.set_tag("model", "linear regession")
    
    mlflow.log_param("train_path", {train_path})
    mlflow.log_param("valid_path", {valid_path})
    
    lr = LinearRegression()
    lr.fit(X_train, y_train)
    mlflow.sklearn.log_model(lr, artifact_path="sklearn-model")

    y_pred = lr.predict(X_val)

    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)
   
    with open('./mlflow/models/linear_regression.bin', 'wb') as f_out:
        pickle.dump(lr, f_out)
        
    with open('./mlflow/models/preprocessor.b', 'wb') as dv_out:
        pickle.dump(dv, dv_out)
        
    mlflow.log_artifact('./mlflow/models/linear_regression.bin', artifact_path='models_pickle')
    mlflow.log_artifact('./mlflow/models/preprocessor.b', artifact_path='preprocessor')

# %% [markdown]
# ### LINEAR REGRESSION - LASSO

# %%
with mlflow.start_run(run_name="model_selection"):
    
    mlflow.set_tag("developer", "surawut")
    mlflow.set_tag("model", "linear regession")
    
    mlflow.log_param("train_path", {train_path})
    mlflow.log_param("valid_path", {valid_path})
    
    
    alpha = 0.1
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)
    
    mlflow.log_param("alpha", alpha)
    mlflow.sklearn.log_model(lr, artifact_path='sklearn_model')
    
    y_pred = lr.predict(X_val)
    
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)
    
    with open('./mlflow/models/lasso.bin', 'wb') as f_out:
        pickle.dump(lr, f_out)
        
    with open('./mlflow/models/preprocessor.b', 'wb') as dv_out:
        pickle.dump(dv, dv_out)
        
    mlflow.log_artifact('./mlflow/models/lasso.bin', artifact_path='models_pickle')
    mlflow.log_artifact('./mlflow/models/preprocessor.b', artifact_path='preprocessor')

# %% [markdown]
# ### XGBOOST

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %% [markdown]
# ### HYPER OPT FOR FINE TUNING

# %%
def objective(params):
    with mlflow.start_run(run_name="fine tuning"):
        mlflow.set_tag("developer", "surawut")
        mlflow.set_tag("model", "hyperopt")
        mlflow.log_params(params)
        
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
        
    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=10,
    trials=Trials()
)
# Out:
# [21:04:18] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:8.89696
# [1]	validation-rmse:6.90666
# [2]	validation-rmse:6.60273
# [3]	validation-rmse:6.52069
# [4]	validation-rmse:6.50768
# [5]	validation-rmse:6.49449
# [6]	validation-rmse:6.48705
# [7]	validation-rmse:6.47447
# [8]	validation-rmse:6.46961
# [9]	validation-rmse:6.46218
# [10]	validation-rmse:6.46143
# [11]	validation-rmse:6.45725
# [12]	validation-rmse:6.45400
# [13]	validation-rmse:6.44865
# [14]	validation-rmse:6.44326
# [15]	validation-rmse:6.43999
# [16]	validation-rmse:6.43487
# [17]	validation-rmse:6.43368
# [18]	validation-rmse:6.43045
# [19]	validation-rmse:6.42946
# [20]	validation-rmse:6.42980
# [21]	validation-rmse:6.42446
# [22]	validation-rmse:6.42841
# [23]	validation-rmse:6.42952
# [24]	validation-rmse:6.42814
# [25]	validation-rmse:6.42637
# [26]	validation-rmse:6.42546
# [27]	validation-rmse:6.43146
# [28]	validation-rmse:6.43042
# [29]	validation-rmse:6.42994
# [30]	validation-rmse:6.42708
# [31]	validation-rmse:6.42500
# [32]	validation-rmse:6.42373
# [33]	validation-rmse:6.42604
# [34]	validation-rmse:6.42605
# [35]	validation-rmse:6.42347
# [36]	validation-rmse:6.42307
# [37]	validation-rmse:6.42303
# [38]	validation-rmse:6.42398
# [39]	validation-rmse:6.42356
# [40]	validation-rmse:6.42467
# [41]	validation-rmse:6.42558
# [42]	validation-rmse:6.42704
# [43]	validation-rmse:6.42725
# [44]	validation-rmse:6.43198
# [45]	validation-rmse:6.43227
# [46]	validation-rmse:6.43236
# [47]	validation-rmse:6.43063
# [48]	validation-rmse:6.43141
# [49]	validation-rmse:6.43052
# [50]	validation-rmse:6.43048
# [51]	validation-rmse:6.43143
# [52]	validation-rmse:6.43298
# [53]	validation-rmse:6.43396
# [54]	validation-rmse:6.43393
# [55]	validation-rmse:6.43447
# [56]	validation-rmse:6.43434
# [57]	validation-rmse:6.43439
# [58]	validation-rmse:6.43563
# [59]	validation-rmse:6.43716
# [60]	validation-rmse:6.44017
# [61]	validation-rmse:6.44027
# [62]	validation-rmse:6.44531
# [63]	validation-rmse:6.44614
# [64]	validation-rmse:6.44915
# [65]	validation-rmse:6.44912
# [66]	validation-rmse:6.44907
# [67]	validation-rmse:6.45035
# [68]	validation-rmse:6.45035
# [69]	validation-rmse:6.45070
# [70]	validation-rmse:6.45177
# [71]	validation-rmse:6.45206
# [72]	validation-rmse:6.45308
# [73]	validation-rmse:6.45289
# [74]	validation-rmse:6.45524
# [75]	validation-rmse:6.45656
# [76]	validation-rmse:6.45770
# [77]	validation-rmse:6.45715
# [78]	validation-rmse:6.45559
# [79]	validation-rmse:6.45624
# [80]	validation-rmse:6.45642
# [81]	validation-rmse:6.45815
# [82]	validation-rmse:6.46124
# [83]	validation-rmse:6.46292
# [84]	validation-rmse:6.46467
# [85]	validation-rmse:6.46493
# [86]	validation-rmse:6.46504
# [87]	validation-rmse:6.46527
# [21:04:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:18.35054
# [1]	validation-rmse:16.01667
# [2]	validation-rmse:14.10598
# [3]	validation-rmse:12.55479
# [4]	validation-rmse:11.30785
# [5]	validation-rmse:10.30597
# [6]	validation-rmse:9.50982
# [7]	validation-rmse:8.88349
# [8]	validation-rmse:8.38974
# [9]	validation-rmse:8.00607
# [10]	validation-rmse:7.70164
# [11]	validation-rmse:7.46976
# [12]	validation-rmse:7.28683
# [13]	validation-rmse:7.14328
# [14]	validation-rmse:7.02844
# [15]	validation-rmse:6.93944
# [16]	validation-rmse:6.86839
# [17]	validation-rmse:6.80934
# [18]	validation-rmse:6.76411
# [19]	validation-rmse:6.72810
# [20]	validation-rmse:6.69866
# [21]	validation-rmse:6.67429
# [22]	validation-rmse:6.65367
# [23]	validation-rmse:6.63619
# [24]	validation-rmse:6.62306
# [25]	validation-rmse:6.61040
# [26]	validation-rmse:6.60123
# [27]	validation-rmse:6.59297
# [28]	validation-rmse:6.58642
# [29]	validation-rmse:6.58077
# [30]	validation-rmse:6.57671
# [31]	validation-rmse:6.57228
# [32]	validation-rmse:6.56924
# [33]	validation-rmse:6.56512
# [34]	validation-rmse:6.56219
# [35]	validation-rmse:6.55943
# [36]	validation-rmse:6.55751
# [37]	validation-rmse:6.55568
# [38]	validation-rmse:6.55344
# [39]	validation-rmse:6.55106
# [40]	validation-rmse:6.54908
# [41]	validation-rmse:6.54660
# [42]	validation-rmse:6.54482
# [43]	validation-rmse:6.54333
# [44]	validation-rmse:6.54159
# [45]	validation-rmse:6.54029
# [46]	validation-rmse:6.53972
# [47]	validation-rmse:6.53835
# [48]	validation-rmse:6.53743
# [49]	validation-rmse:6.53677
# [50]	validation-rmse:6.53563
# [51]	validation-rmse:6.53462
# [52]	validation-rmse:6.53331
# [53]	validation-rmse:6.53251
# [54]	validation-rmse:6.53167
# [55]	validation-rmse:6.53104
# [56]	validation-rmse:6.53044
# [57]	validation-rmse:6.52803
# [58]	validation-rmse:6.52702
# [59]	validation-rmse:6.52597
# [60]	validation-rmse:6.52446
# [61]	validation-rmse:6.52402
# [62]	validation-rmse:6.52293
# [63]	validation-rmse:6.52220
# [64]	validation-rmse:6.52175
# [65]	validation-rmse:6.52060
# [66]	validation-rmse:6.52022
# [67]	validation-rmse:6.51877
# [68]	validation-rmse:6.51796
# [69]	validation-rmse:6.51723
# [70]	validation-rmse:6.51666
# [71]	validation-rmse:6.51535
# [72]	validation-rmse:6.51467
# [73]	validation-rmse:6.51387
# [74]	validation-rmse:6.51319
# [75]	validation-rmse:6.51250
# [76]	validation-rmse:6.51181
# [77]	validation-rmse:6.51121
# [78]	validation-rmse:6.51042
# [79]	validation-rmse:6.50946
# [80]	validation-rmse:6.50788
# [81]	validation-rmse:6.50725
# [82]	validation-rmse:6.50649
# [83]	validation-rmse:6.50604
# [84]	validation-rmse:6.50532
# [85]	validation-rmse:6.50436
# [86]	validation-rmse:6.50354
# [87]	validation-rmse:6.50297
# [88]	validation-rmse:6.50230
# [89]	validation-rmse:6.50206
# [90]	validation-rmse:6.50141
# [91]	validation-rmse:6.50068
# [92]	validation-rmse:6.50008
# [93]	validation-rmse:6.49971
# [94]	validation-rmse:6.49900
# [95]	validation-rmse:6.49841
# [96]	validation-rmse:6.49788
# [97]	validation-rmse:6.49670
# [98]	validation-rmse:6.49625
# [99]	validation-rmse:6.49618
# [100]	validation-rmse:6.49523
# [101]	validation-rmse:6.49449
# [102]	validation-rmse:6.49365
# [103]	validation-rmse:6.49330
# [104]	validation-rmse:6.49283
# [105]	validation-rmse:6.49222
# [106]	validation-rmse:6.49180
# [107]	validation-rmse:6.49123
# [108]	validation-rmse:6.49030
# [109]	validation-rmse:6.48980
# [110]	validation-rmse:6.48882
# [111]	validation-rmse:6.48871
# [112]	validation-rmse:6.48810
# [113]	validation-rmse:6.48741
# [114]	validation-rmse:6.48681
# [115]	validation-rmse:6.48643
# [116]	validation-rmse:6.48620
# [117]	validation-rmse:6.48582
# [118]	validation-rmse:6.48523
# [119]	validation-rmse:6.48455
# [120]	validation-rmse:6.48438
# [121]	validation-rmse:6.48388
# [122]	validation-rmse:6.48362
# [123]	validation-rmse:6.48324
# [124]	validation-rmse:6.48276
# [125]	validation-rmse:6.48268
# [126]	validation-rmse:6.48227
# [127]	validation-rmse:6.48196
# [128]	validation-rmse:6.48132
# [129]	validation-rmse:6.48080
# [130]	validation-rmse:6.48005
# [131]	validation-rmse:6.47957
# [132]	validation-rmse:6.47924
# [133]	validation-rmse:6.47866
# [134]	validation-rmse:6.47841
# [135]	validation-rmse:6.47785
# [136]	validation-rmse:6.47766
# [137]	validation-rmse:6.47706
# [138]	validation-rmse:6.47615
# [139]	validation-rmse:6.47561
# [140]	validation-rmse:6.47520
# [141]	validation-rmse:6.47426
# [142]	validation-rmse:6.47370
# [143]	validation-rmse:6.47315
# [144]	validation-rmse:6.47260
# [145]	validation-rmse:6.47205
# [146]	validation-rmse:6.47172
# [147]	validation-rmse:6.47179
# [148]	validation-rmse:6.47109
# [149]	validation-rmse:6.47028
# [150]	validation-rmse:6.46980
# [151]	validation-rmse:6.46963
# [152]	validation-rmse:6.46914
# [153]	validation-rmse:6.46905
# [154]	validation-rmse:6.46871
# [155]	validation-rmse:6.46809
# [156]	validation-rmse:6.46747
# [157]	validation-rmse:6.46722
# [158]	validation-rmse:6.46647
# [159]	validation-rmse:6.46565
# [160]	validation-rmse:6.46529
# [161]	validation-rmse:6.46484
# [162]	validation-rmse:6.46463
# [163]	validation-rmse:6.46412
# [164]	validation-rmse:6.46389
# [165]	validation-rmse:6.46306
# [166]	validation-rmse:6.46176
# [167]	validation-rmse:6.46100
# [168]	validation-rmse:6.46041
# [169]	validation-rmse:6.45980
# [170]	validation-rmse:6.45974
# [171]	validation-rmse:6.45950
# [172]	validation-rmse:6.45920
# [173]	validation-rmse:6.45876
# [174]	validation-rmse:6.45857
# [175]	validation-rmse:6.45820
# [176]	validation-rmse:6.45773
# [177]	validation-rmse:6.45745
# [178]	validation-rmse:6.45716
# [179]	validation-rmse:6.45740
# [180]	validation-rmse:6.45726
# [181]	validation-rmse:6.45703
# [182]	validation-rmse:6.45699
# [183]	validation-rmse:6.45642
# [184]	validation-rmse:6.45585
# [185]	validation-rmse:6.45559
# [186]	validation-rmse:6.45539
# [187]	validation-rmse:6.45525
# [188]	validation-rmse:6.45498
# [189]	validation-rmse:6.45451
# [190]	validation-rmse:6.45345
# [191]	validation-rmse:6.45326
# [192]	validation-rmse:6.45354
# [193]	validation-rmse:6.45296
# [194]	validation-rmse:6.45268
# [195]	validation-rmse:6.45205
# [196]	validation-rmse:6.45226
# [197]	validation-rmse:6.45185
# [198]	validation-rmse:6.45160
# [199]	validation-rmse:6.45130
# [200]	validation-rmse:6.45076
# [201]	validation-rmse:6.45058
# [202]	validation-rmse:6.44988
# [203]	validation-rmse:6.44954
# [204]	validation-rmse:6.44965
# [205]	validation-rmse:6.44908
# [206]	validation-rmse:6.44919
# [207]	validation-rmse:6.44882
# [208]	validation-rmse:6.44813
# [209]	validation-rmse:6.44793
# [210]	validation-rmse:6.44784
# [211]	validation-rmse:6.44754
# [212]	validation-rmse:6.44772
# [213]	validation-rmse:6.44776
# [214]	validation-rmse:6.44770
# [215]	validation-rmse:6.44735
# [216]	validation-rmse:6.44700
# [217]	validation-rmse:6.44662
# [218]	validation-rmse:6.44625
# [219]	validation-rmse:6.44597
# [220]	validation-rmse:6.44547
# [221]	validation-rmse:6.44546
# [222]	validation-rmse:6.44500
# [223]	validation-rmse:6.44473
# [224]	validation-rmse:6.44443
# [225]	validation-rmse:6.44411
# [226]	validation-rmse:6.44377
# [227]	validation-rmse:6.44371
# [228]	validation-rmse:6.44349
# [229]	validation-rmse:6.44317
# [230]	validation-rmse:6.44279
# [231]	validation-rmse:6.44243
# [232]	validation-rmse:6.44192
# [233]	validation-rmse:6.44222
# [234]	validation-rmse:6.44206
# [235]	validation-rmse:6.44146
# [236]	validation-rmse:6.44092
# [237]	validation-rmse:6.44004
# [238]	validation-rmse:6.44030
# [239]	validation-rmse:6.44054
# [240]	validation-rmse:6.44117
# [241]	validation-rmse:6.44082
# [242]	validation-rmse:6.44056
# [243]	validation-rmse:6.44042
# [244]	validation-rmse:6.44029
# [245]	validation-rmse:6.44015
# [246]	validation-rmse:6.44014
# [247]	validation-rmse:6.44040
# [248]	validation-rmse:6.43975
# [249]	validation-rmse:6.43973
# [250]	validation-rmse:6.43956
# [251]	validation-rmse:6.43924
# [252]	validation-rmse:6.43871
# [253]	validation-rmse:6.43853
# [254]	validation-rmse:6.43820
# [255]	validation-rmse:6.43777
# [256]	validation-rmse:6.43743
# [257]	validation-rmse:6.43715
# [258]	validation-rmse:6.43674
# [259]	validation-rmse:6.43666
# [260]	validation-rmse:6.43618
# [261]	validation-rmse:6.43599
# [262]	validation-rmse:6.43587
# [263]	validation-rmse:6.43573
# [264]	validation-rmse:6.43534
# [265]	validation-rmse:6.43507
# [266]	validation-rmse:6.43484
# [267]	validation-rmse:6.43466
# [268]	validation-rmse:6.43476
# [269]	validation-rmse:6.43452
# [270]	validation-rmse:6.43416
# [271]	validation-rmse:6.43375
# [272]	validation-rmse:6.43384
# [273]	validation-rmse:6.43341
# [274]	validation-rmse:6.43281
# [275]	validation-rmse:6.43250
# [276]	validation-rmse:6.43212
# [277]	validation-rmse:6.43206
# [278]	validation-rmse:6.43204
# [279]	validation-rmse:6.43218
# [280]	validation-rmse:6.43197
# [281]	validation-rmse:6.43148
# [282]	validation-rmse:6.43161
# [283]	validation-rmse:6.43147
# [284]	validation-rmse:6.43130
# [285]	validation-rmse:6.43142
# [286]	validation-rmse:6.43164
# [287]	validation-rmse:6.43122
# [288]	validation-rmse:6.43097
# [289]	validation-rmse:6.43070
# [290]	validation-rmse:6.43093
# [291]	validation-rmse:6.43098
# [292]	validation-rmse:6.43086
# [293]	validation-rmse:6.43095
# [294]	validation-rmse:6.43059
# [295]	validation-rmse:6.43018
# [296]	validation-rmse:6.42992
# [297]	validation-rmse:6.42955
# [298]	validation-rmse:6.42957
# [299]	validation-rmse:6.42929
# [300]	validation-rmse:6.42905
# [301]	validation-rmse:6.42896
# [302]	validation-rmse:6.42889
# [303]	validation-rmse:6.42727
# [304]	validation-rmse:6.42696
# [305]	validation-rmse:6.42667
# [306]	validation-rmse:6.42652
# [307]	validation-rmse:6.42607
# [308]	validation-rmse:6.42554
# [309]	validation-rmse:6.42543
# [310]	validation-rmse:6.42479
# [311]	validation-rmse:6.42465
# [312]	validation-rmse:6.42444
# [313]	validation-rmse:6.42432
# [314]	validation-rmse:6.42389
# [315]	validation-rmse:6.42366
# [316]	validation-rmse:6.42366
# [317]	validation-rmse:6.42360
# [318]	validation-rmse:6.42338
# [319]	validation-rmse:6.42338
# [320]	validation-rmse:6.42334
# [321]	validation-rmse:6.42343
# [322]	validation-rmse:6.42343
# [323]	validation-rmse:6.42321
# [324]	validation-rmse:6.42313
# [325]	validation-rmse:6.42304
# [326]	validation-rmse:6.42322
# [327]	validation-rmse:6.42316
# [328]	validation-rmse:6.42300
# [329]	validation-rmse:6.42295
# [330]	validation-rmse:6.42256
# [331]	validation-rmse:6.42241
# [332]	validation-rmse:6.42222
# [333]	validation-rmse:6.42181
# [334]	validation-rmse:6.42242
# [335]	validation-rmse:6.42170
# [336]	validation-rmse:6.42153
# [337]	validation-rmse:6.42124
# [338]	validation-rmse:6.42078
# [339]	validation-rmse:6.42083
# [340]	validation-rmse:6.42068
# [341]	validation-rmse:6.42074
# [342]	validation-rmse:6.42061
# [343]	validation-rmse:6.42041
# [344]	validation-rmse:6.42015
# [345]	validation-rmse:6.42003
# [346]	validation-rmse:6.41981
# [347]	validation-rmse:6.41939
# [348]	validation-rmse:6.41949
# [349]	validation-rmse:6.41922
# [350]	validation-rmse:6.41908
# [351]	validation-rmse:6.41952
# [352]	validation-rmse:6.41945
# [353]	validation-rmse:6.41906
# [354]	validation-rmse:6.41879
# [355]	validation-rmse:6.41855
# [356]	validation-rmse:6.41867
# [357]	validation-rmse:6.41827
# [358]	validation-rmse:6.41774
# [359]	validation-rmse:6.41725
# [360]	validation-rmse:6.41699
# [361]	validation-rmse:6.41669
# [362]	validation-rmse:6.41673
# [363]	validation-rmse:6.41667
# [364]	validation-rmse:6.41641
# [365]	validation-rmse:6.41617
# [366]	validation-rmse:6.41595
# [367]	validation-rmse:6.41577
# [368]	validation-rmse:6.41550
# [369]	validation-rmse:6.41569
# [370]	validation-rmse:6.41579
# [371]	validation-rmse:6.41570
# [372]	validation-rmse:6.41569
# [373]	validation-rmse:6.41583
# [374]	validation-rmse:6.41624
# [375]	validation-rmse:6.41605
# [376]	validation-rmse:6.41585
# [377]	validation-rmse:6.41597
# [378]	validation-rmse:6.41555
# [379]	validation-rmse:6.41560
# [380]	validation-rmse:6.41550
# [381]	validation-rmse:6.41531
# [382]	validation-rmse:6.41538
# [383]	validation-rmse:6.41508
# [384]	validation-rmse:6.41503
# [385]	validation-rmse:6.41493
# [386]	validation-rmse:6.41497
# [387]	validation-rmse:6.41479
# [388]	validation-rmse:6.41447
# [389]	validation-rmse:6.41429
# [390]	validation-rmse:6.41458
# [391]	validation-rmse:6.41457
# [392]	validation-rmse:6.41438
# [393]	validation-rmse:6.41428
# [394]	validation-rmse:6.41404
# [395]	validation-rmse:6.41362
# [396]	validation-rmse:6.41366
# [397]	validation-rmse:6.41384
# [398]	validation-rmse:6.41369
# [399]	validation-rmse:6.41341
# [400]	validation-rmse:6.41329
# [401]	validation-rmse:6.41317
# [402]	validation-rmse:6.41297
# [403]	validation-rmse:6.41276
# [404]	validation-rmse:6.41257
# [405]	validation-rmse:6.41241
# [406]	validation-rmse:6.41237
# [407]	validation-rmse:6.41215
# [408]	validation-rmse:6.41182
# [409]	validation-rmse:6.41178
# [410]	validation-rmse:6.41160
# [411]	validation-rmse:6.41128
# [412]	validation-rmse:6.41107
# [413]	validation-rmse:6.41078
# [414]	validation-rmse:6.41073
# [415]	validation-rmse:6.41076
# [416]	validation-rmse:6.41074
# [417]	validation-rmse:6.41076
# [418]	validation-rmse:6.41052
# [419]	validation-rmse:6.41068
# [420]	validation-rmse:6.41079
# [421]	validation-rmse:6.41067
# [422]	validation-rmse:6.41063
# [423]	validation-rmse:6.41044
# [424]	validation-rmse:6.40986
# [425]	validation-rmse:6.40993
# [426]	validation-rmse:6.40979
# [427]	validation-rmse:6.40962
# [428]	validation-rmse:6.40949
# [429]	validation-rmse:6.40957
# [430]	validation-rmse:6.40941
# [431]	validation-rmse:6.40940
# [432]	validation-rmse:6.40897
# [433]	validation-rmse:6.40814
# [434]	validation-rmse:6.40825
# [435]	validation-rmse:6.40798
# [436]	validation-rmse:6.40798
# [437]	validation-rmse:6.40798
# [438]	validation-rmse:6.40770
# [439]	validation-rmse:6.40764
# [440]	validation-rmse:6.40779
# [441]	validation-rmse:6.40798
# [442]	validation-rmse:6.40777
# [443]	validation-rmse:6.40757
# [444]	validation-rmse:6.40744
# [445]	validation-rmse:6.40740
# [446]	validation-rmse:6.40751
# [447]	validation-rmse:6.40754
# [448]	validation-rmse:6.40766
# [449]	validation-rmse:6.40737
# [450]	validation-rmse:6.40734
# [451]	validation-rmse:6.40718
# [452]	validation-rmse:6.40687
# [453]	validation-rmse:6.40654
# [454]	validation-rmse:6.40639
# [455]	validation-rmse:6.40618
# [456]	validation-rmse:6.40609
# [457]	validation-rmse:6.40619
# [458]	validation-rmse:6.40610
# [459]	validation-rmse:6.40609
# [460]	validation-rmse:6.40596
# [461]	validation-rmse:6.40565
# [462]	validation-rmse:6.40548
# [463]	validation-rmse:6.40533
# [464]	validation-rmse:6.40509
# [465]	validation-rmse:6.40503
# [466]	validation-rmse:6.40524
# [467]	validation-rmse:6.40543
# [468]	validation-rmse:6.40532
# [469]	validation-rmse:6.40546
# [470]	validation-rmse:6.40536
# [471]	validation-rmse:6.40534
# [472]	validation-rmse:6.40535
# [473]	validation-rmse:6.40539
# [474]	validation-rmse:6.40536
# [475]	validation-rmse:6.40547
# [476]	validation-rmse:6.40529
# [477]	validation-rmse:6.40515
# [478]	validation-rmse:6.40521
# [479]	validation-rmse:6.40515
# [480]	validation-rmse:6.40508
# [481]	validation-rmse:6.40479
# [482]	validation-rmse:6.40494
# [483]	validation-rmse:6.40481
# [484]	validation-rmse:6.40454
# [485]	validation-rmse:6.40442
# [486]	validation-rmse:6.40447
# [487]	validation-rmse:6.40447
# [488]	validation-rmse:6.40428
# [489]	validation-rmse:6.40435
# [490]	validation-rmse:6.40408
# [491]	validation-rmse:6.40405
# [492]	validation-rmse:6.40400
# [493]	validation-rmse:6.40382
# [494]	validation-rmse:6.40370
# [495]	validation-rmse:6.40358
# [496]	validation-rmse:6.40372
# [497]	validation-rmse:6.40374
# [498]	validation-rmse:6.40370
# [499]	validation-rmse:6.40380
# [500]	validation-rmse:6.40370
# [501]	validation-rmse:6.40359
# [502]	validation-rmse:6.40375
# [503]	validation-rmse:6.40386
# [504]	validation-rmse:6.40396
# [505]	validation-rmse:6.40329
# [506]	validation-rmse:6.40319
# [507]	validation-rmse:6.40320
# [508]	validation-rmse:6.40305
# [509]	validation-rmse:6.40277
# [510]	validation-rmse:6.40290
# [511]	validation-rmse:6.40282
# [512]	validation-rmse:6.40274
# [513]	validation-rmse:6.40281
# [514]	validation-rmse:6.40270
# [515]	validation-rmse:6.40249
# [516]	validation-rmse:6.40227
# [517]	validation-rmse:6.40239
# [518]	validation-rmse:6.40253
# [519]	validation-rmse:6.40281
# [520]	validation-rmse:6.40291
# [521]	validation-rmse:6.40271
# [522]	validation-rmse:6.40287
# [523]	validation-rmse:6.40280
# [524]	validation-rmse:6.40259
# [525]	validation-rmse:6.40262
# [526]	validation-rmse:6.40281
# [527]	validation-rmse:6.40275
# [528]	validation-rmse:6.40258
# [529]	validation-rmse:6.40262
# [530]	validation-rmse:6.40269
# [531]	validation-rmse:6.40292
# [532]	validation-rmse:6.40272
# [533]	validation-rmse:6.40229
# ...
# [985]	validation-rmse:6.54243
# [986]	validation-rmse:6.54241
# [987]	validation-rmse:6.54234
# [988]	validation-rmse:6.54234
# [989]	validation-rmse:6.54232
# [990]	validation-rmse:6.54228
# [991]	validation-rmse:6.54224
# [992]	validation-rmse:6.54232
# [993]	validation-rmse:6.54237
# [994]	validation-rmse:6.54237
# [995]	validation-rmse:6.54236
# [996]	validation-rmse:6.54226
# [997]	validation-rmse:6.54222
# [998]	validation-rmse:6.54219
# [999]	validation-rmse:6.54216
# [21:10:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:18.11158
# [1]	validation-rmse:15.62577
# [2]	validation-rmse:13.63432
# [3]	validation-rmse:12.05593
# [4]	validation-rmse:10.81516
# [5]	validation-rmse:9.84974
# [6]	validation-rmse:9.10457
# [7]	validation-rmse:8.53468
# [8]	validation-rmse:8.10290
# [9]	validation-rmse:7.77581
# [10]	validation-rmse:7.52801
# [11]	validation-rmse:7.33877
# [12]	validation-rmse:7.19547
# [13]	validation-rmse:7.08707
# [14]	validation-rmse:7.00176
# [15]	validation-rmse:6.93790
# [16]	validation-rmse:6.88676
# [17]	validation-rmse:6.84669
# [18]	validation-rmse:6.81371
# [19]	validation-rmse:6.78774
# [20]	validation-rmse:6.76604
# [21]	validation-rmse:6.74957
# [22]	validation-rmse:6.73619
# [23]	validation-rmse:6.72419
# [24]	validation-rmse:6.71423
# [25]	validation-rmse:6.70419
# [26]	validation-rmse:6.69703
# [27]	validation-rmse:6.69194
# [28]	validation-rmse:6.68616
# [29]	validation-rmse:6.68153
# [30]	validation-rmse:6.67814
# [31]	validation-rmse:6.67518
# [32]	validation-rmse:6.67239
# [33]	validation-rmse:6.67080
# [34]	validation-rmse:6.66866
# [35]	validation-rmse:6.66737
# [36]	validation-rmse:6.66613
# [37]	validation-rmse:6.66496
# [38]	validation-rmse:6.66385
# [39]	validation-rmse:6.66303
# [40]	validation-rmse:6.66233
# [41]	validation-rmse:6.66176
# [42]	validation-rmse:6.66057
# [43]	validation-rmse:6.66000
# [44]	validation-rmse:6.65947
# [45]	validation-rmse:6.65916
# [46]	validation-rmse:6.65885
# [47]	validation-rmse:6.65815
# [48]	validation-rmse:6.65791
# [49]	validation-rmse:6.65755
# [50]	validation-rmse:6.65736
# [51]	validation-rmse:6.65698
# [52]	validation-rmse:6.65689
# [53]	validation-rmse:6.65661
# [54]	validation-rmse:6.65628
# [55]	validation-rmse:6.65580
# [56]	validation-rmse:6.65567
# [57]	validation-rmse:6.65527
# [58]	validation-rmse:6.65520
# [59]	validation-rmse:6.65484
# [60]	validation-rmse:6.65474
# [61]	validation-rmse:6.65430
# [62]	validation-rmse:6.65441
# [63]	validation-rmse:6.65435
# [64]	validation-rmse:6.65431
# [65]	validation-rmse:6.65393
# [66]	validation-rmse:6.65393
# [67]	validation-rmse:6.65344
# [68]	validation-rmse:6.65309
# [69]	validation-rmse:6.65314
# [70]	validation-rmse:6.65316
# [71]	validation-rmse:6.65312
# [72]	validation-rmse:6.65324
# [73]	validation-rmse:6.65307
# [74]	validation-rmse:6.65265
# [75]	validation-rmse:6.65279
# [76]	validation-rmse:6.65267
# [77]	validation-rmse:6.65242
# [78]	validation-rmse:6.65238
# [79]	validation-rmse:6.65239
# [80]	validation-rmse:6.65240
# [81]	validation-rmse:6.65201
# [82]	validation-rmse:6.65180
# [83]	validation-rmse:6.65198
# [84]	validation-rmse:6.65193
# [85]	validation-rmse:6.65172
# [86]	validation-rmse:6.65160
# [87]	validation-rmse:6.65121
# [88]	validation-rmse:6.65115
# [89]	validation-rmse:6.65108
# [90]	validation-rmse:6.65061
# [91]	validation-rmse:6.65062
# [92]	validation-rmse:6.65038
# [93]	validation-rmse:6.64996
# [94]	validation-rmse:6.65023
# [95]	validation-rmse:6.64999
# [96]	validation-rmse:6.64998
# [97]	validation-rmse:6.64984
# [98]	validation-rmse:6.64981
# [99]	validation-rmse:6.64954
# [100]	validation-rmse:6.64943
# [101]	validation-rmse:6.64933
# [102]	validation-rmse:6.64940
# [103]	validation-rmse:6.64934
# [104]	validation-rmse:6.64960
# [105]	validation-rmse:6.64863
# [106]	validation-rmse:6.64863
# [107]	validation-rmse:6.64843
# [108]	validation-rmse:6.64815
# [109]	validation-rmse:6.64825
# [110]	validation-rmse:6.64806
# [111]	validation-rmse:6.64776
# [112]	validation-rmse:6.64790
# [113]	validation-rmse:6.64754
# [114]	validation-rmse:6.64742
# [115]	validation-rmse:6.64758
# [116]	validation-rmse:6.64764
# [117]	validation-rmse:6.64719
# [118]	validation-rmse:6.64699
# [119]	validation-rmse:6.64650
# [120]	validation-rmse:6.64652
# [121]	validation-rmse:6.64624
# [122]	validation-rmse:6.64605
# [123]	validation-rmse:6.64591
# [124]	validation-rmse:6.64577
# [125]	validation-rmse:6.64603
# [126]	validation-rmse:6.64592
# [127]	validation-rmse:6.64612
# [128]	validation-rmse:6.64608
# [129]	validation-rmse:6.64600
# [130]	validation-rmse:6.64574
# [131]	validation-rmse:6.64600
# [132]	validation-rmse:6.64598
# [133]	validation-rmse:6.64604
# [134]	validation-rmse:6.64595
# [135]	validation-rmse:6.64659
# [136]	validation-rmse:6.64674
# [137]	validation-rmse:6.64690
# [138]	validation-rmse:6.64704
# [139]	validation-rmse:6.64748
# [140]	validation-rmse:6.64727
# [141]	validation-rmse:6.64729
# [142]	validation-rmse:6.64728
# [143]	validation-rmse:6.64688
# [144]	validation-rmse:6.64710
# [145]	validation-rmse:6.64771
# [146]	validation-rmse:6.64804
# [147]	validation-rmse:6.64789
# [148]	validation-rmse:6.64785
# [149]	validation-rmse:6.64806
# [150]	validation-rmse:6.64777
# [151]	validation-rmse:6.64790
# [152]	validation-rmse:6.64782
# [153]	validation-rmse:6.64761
# [154]	validation-rmse:6.64752
# [155]	validation-rmse:6.64745
# [156]	validation-rmse:6.64747
# [157]	validation-rmse:6.64760
# [158]	validation-rmse:6.64765
# [159]	validation-rmse:6.64741
# [160]	validation-rmse:6.64736
# [161]	validation-rmse:6.64747
# [162]	validation-rmse:6.64745
# [163]	validation-rmse:6.64769
# [164]	validation-rmse:6.64786
# [165]	validation-rmse:6.64786
# [166]	validation-rmse:6.64776
# [167]	validation-rmse:6.64766
# [168]	validation-rmse:6.64753
# [169]	validation-rmse:6.64699
# [170]	validation-rmse:6.64720
# [171]	validation-rmse:6.64725
# [172]	validation-rmse:6.64715
# [173]	validation-rmse:6.64719
# [174]	validation-rmse:6.64723
# [175]	validation-rmse:6.64725
# [176]	validation-rmse:6.64721
# [177]	validation-rmse:6.64708
# [178]	validation-rmse:6.64708
# [179]	validation-rmse:6.64670
# [180]	validation-rmse:6.64678
# 100%|██████████| 10/10 [06:47<00:00, 40.73s/trial, best loss: 6.361559483741776]

# %% [markdown]
# ### XGBOOST OPTIMIZATION HYPER PARAMETER WITH HYPEROPT

# %%
with mlflow.start_run(run_name="tuned_hyper_params"):
    
    mlflow.xgboost.autolog(disable=True)
    mlflow.set_tag("developer", "surawut")
    mlflow.set_tag("model", "xgboost")
    
    best_params = {
        'learning_rate': 0.2053232728477489,
        'max_depth': 49,
        'min_child_weight': 2.744970249660763,
        'objective': 'reg:linear',
        'reg_alpha': 0.012966352401600332,
        'reg_lambda': 0.16922535923434157,
        'seed': 42
    }
    
    mlflow.log_params(best_params)
    
    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )
    
    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)
   
    with open('./mlflow/models/preprocessor.b', 'wb') as dv_out:
        pickle.dump(dv, dv_out)
        
    with open('./mlflow/models/xgboost.bin', 'wb') as f_out:
        pickle.dump(booster, f_out)
        
    mlflow.log_artifact('./mlflow/models/xgboost.bin', artifact_path='models_pickle')
    mlflow.log_artifact('./mlflow/models/preprocessor.b', artifact_path='preprocessor')
    
    mlflow.xgboost.log_model(booster, artifact_path='models_xgboost')
# Out:
# [10:44:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:17.54287
# [1]	validation-rmse:14.72296
# [2]	validation-rmse:12.57072
# [3]	validation-rmse:10.95021
# [4]	validation-rmse:9.74298
# [5]	validation-rmse:8.85627
# [6]	validation-rmse:8.21168
# [7]	validation-rmse:7.74695
# [8]	validation-rmse:7.41107
# [9]	validation-rmse:7.17202
# [10]	validation-rmse:6.99769
# [11]	validation-rmse:6.87153
# [12]	validation-rmse:6.77912
# [13]	validation-rmse:6.70846
# [14]	validation-rmse:6.65632
# [15]	validation-rmse:6.61415
# [16]	validation-rmse:6.58222
# [17]	validation-rmse:6.55632
# [18]	validation-rmse:6.53600
# [19]	validation-rmse:6.52031
# [20]	validation-rmse:6.50897
# [21]	validation-rmse:6.49880
# [22]	validation-rmse:6.49085
# [23]	validation-rmse:6.48648
# [24]	validation-rmse:6.47979
# [25]	validation-rmse:6.47616
# [26]	validation-rmse:6.47225
# [27]	validation-rmse:6.46930
# [28]	validation-rmse:6.46560
# [29]	validation-rmse:6.46267
# [30]	validation-rmse:6.45940
# [31]	validation-rmse:6.45636
# [32]	validation-rmse:6.45441
# [33]	validation-rmse:6.45184
# [34]	validation-rmse:6.45006
# [35]	validation-rmse:6.44902
# [36]	validation-rmse:6.44694
# [37]	validation-rmse:6.44508
# [38]	validation-rmse:6.44247
# [39]	validation-rmse:6.44108
# [40]	validation-rmse:6.43933
# [41]	validation-rmse:6.43752
# [42]	validation-rmse:6.43597
# [43]	validation-rmse:6.43469
# [44]	validation-rmse:6.43336
# [45]	validation-rmse:6.43204
# [46]	validation-rmse:6.43108
# [47]	validation-rmse:6.42968
# [48]	validation-rmse:6.42766
# [49]	validation-rmse:6.42644
# [50]	validation-rmse:6.42521
# [51]	validation-rmse:6.42422
# [52]	validation-rmse:6.42348
# [53]	validation-rmse:6.42219
# [54]	validation-rmse:6.42127
# [55]	validation-rmse:6.42055
# [56]	validation-rmse:6.41892
# [57]	validation-rmse:6.41822
# [58]	validation-rmse:6.41733
# [59]	validation-rmse:6.41670
# [60]	validation-rmse:6.41559
# [61]	validation-rmse:6.41504
# [62]	validation-rmse:6.41343
# [63]	validation-rmse:6.41255
# [64]	validation-rmse:6.41159
# [65]	validation-rmse:6.41105
# [66]	validation-rmse:6.40985
# [67]	validation-rmse:6.40852
# [68]	validation-rmse:6.40763
# [69]	validation-rmse:6.40698
# [70]	validation-rmse:6.40591
# [71]	validation-rmse:6.40510
# [72]	validation-rmse:6.40480
# [73]	validation-rmse:6.40337
# [74]	validation-rmse:6.40284
# [75]	validation-rmse:6.40210
# [76]	validation-rmse:6.40129
# [77]	validation-rmse:6.40081
# [78]	validation-rmse:6.40028
# [79]	validation-rmse:6.39992
# [80]	validation-rmse:6.39903
# [81]	validation-rmse:6.39871
# [82]	validation-rmse:6.39819
# [83]	validation-rmse:6.39757
# [84]	validation-rmse:6.39702
# [85]	validation-rmse:6.39640
# [86]	validation-rmse:6.39551
# [87]	validation-rmse:6.39465
# [88]	validation-rmse:6.39407
# [89]	validation-rmse:6.39365
# [90]	validation-rmse:6.39359
# [91]	validation-rmse:6.39332
# [92]	validation-rmse:6.39250
# [93]	validation-rmse:6.39233
# [94]	validation-rmse:6.39194
# [95]	validation-rmse:6.39165
# [96]	validation-rmse:6.39107
# [97]	validation-rmse:6.39073
# [98]	validation-rmse:6.39003
# [99]	validation-rmse:6.38995
# [100]	validation-rmse:6.38911
# [101]	validation-rmse:6.38844
# [102]	validation-rmse:6.38773
# [103]	validation-rmse:6.38746
# [104]	validation-rmse:6.38712
# [105]	validation-rmse:6.38647
# [106]	validation-rmse:6.38580
# [107]	validation-rmse:6.38555
# [108]	validation-rmse:6.38485
# [109]	validation-rmse:6.38408
# [110]	validation-rmse:6.38378
# [111]	validation-rmse:6.38358
# [112]	validation-rmse:6.38262
# [113]	validation-rmse:6.38239
# [114]	validation-rmse:6.38211
# [115]	validation-rmse:6.38182
# [116]	validation-rmse:6.38191
# [117]	validation-rmse:6.38129
# [118]	validation-rmse:6.38089
# [119]	validation-rmse:6.38068
# [120]	validation-rmse:6.38052
# [121]	validation-rmse:6.38019
# [122]	validation-rmse:6.38000
# [123]	validation-rmse:6.37965
# [124]	validation-rmse:6.37955
# [125]	validation-rmse:6.37874
# [126]	validation-rmse:6.37838
# [127]	validation-rmse:6.37815
# [128]	validation-rmse:6.37776
# [129]	validation-rmse:6.37747
# [130]	validation-rmse:6.37744
# [131]	validation-rmse:6.37708
# [132]	validation-rmse:6.37665
# [133]	validation-rmse:6.37679
# [134]	validation-rmse:6.37632
# [135]	validation-rmse:6.37580
# [136]	validation-rmse:6.37535
# [137]	validation-rmse:6.37515
# [138]	validation-rmse:6.37496
# [139]	validation-rmse:6.37469
# [140]	validation-rmse:6.37405
# [141]	validation-rmse:6.37430
# [142]	validation-rmse:6.37419
# [143]	validation-rmse:6.37428
# [144]	validation-rmse:6.37439
# [145]	validation-rmse:6.37420
# [146]	validation-rmse:6.37387
# [147]	validation-rmse:6.37302
# [148]	validation-rmse:6.37230
# [149]	validation-rmse:6.37149
# [150]	validation-rmse:6.37112
# [151]	validation-rmse:6.37117
# [152]	validation-rmse:6.37057
# [153]	validation-rmse:6.37070
# [154]	validation-rmse:6.37054
# [155]	validation-rmse:6.36996
# [156]	validation-rmse:6.36961
# [157]	validation-rmse:6.36961
# [158]	validation-rmse:6.36954
# [159]	validation-rmse:6.36905
# [160]	validation-rmse:6.36843
# [161]	validation-rmse:6.36838
# [162]	validation-rmse:6.36862
# [163]	validation-rmse:6.36852
# [164]	validation-rmse:6.36848
# [165]	validation-rmse:6.36819
# [166]	validation-rmse:6.36809
# [167]	validation-rmse:6.36797
# [168]	validation-rmse:6.36790
# [169]	validation-rmse:6.36845
# [170]	validation-rmse:6.36843
# [171]	validation-rmse:6.36831
# [172]	validation-rmse:6.36830
# [173]	validation-rmse:6.36820
# [174]	validation-rmse:6.36811
# [175]	validation-rmse:6.36770
# [176]	validation-rmse:6.36740
# [177]	validation-rmse:6.36729
# [178]	validation-rmse:6.36722
# [179]	validation-rmse:6.36694
# [180]	validation-rmse:6.36676
# [181]	validation-rmse:6.36623
# [182]	validation-rmse:6.36575
# [183]	validation-rmse:6.36564
# [184]	validation-rmse:6.36599
# [185]	validation-rmse:6.36586
# [186]	validation-rmse:6.36570
# [187]	validation-rmse:6.36565
# [188]	validation-rmse:6.36506
# [189]	validation-rmse:6.36483
# [190]	validation-rmse:6.36467
# [191]	validation-rmse:6.36434
# [192]	validation-rmse:6.36428
# [193]	validation-rmse:6.36424
# [194]	validation-rmse:6.36404
# [195]	validation-rmse:6.36520
# [196]	validation-rmse:6.36500
# [197]	validation-rmse:6.36483
# [198]	validation-rmse:6.36457
# [199]	validation-rmse:6.36468
# [200]	validation-rmse:6.36463
# [201]	validation-rmse:6.36405
# [202]	validation-rmse:6.36449
# [203]	validation-rmse:6.36475
# [204]	validation-rmse:6.36455
# [205]	validation-rmse:6.36443
# [206]	validation-rmse:6.36452
# [207]	validation-rmse:6.36453
# [208]	validation-rmse:6.36457
# [209]	validation-rmse:6.36434
# [210]	validation-rmse:6.36436
# [211]	validation-rmse:6.36427
# [212]	validation-rmse:6.36424
# [213]	validation-rmse:6.36400
# [214]	validation-rmse:6.36380
# [215]	validation-rmse:6.36463
# [216]	validation-rmse:6.36477
# [217]	validation-rmse:6.36454
# [218]	validation-rmse:6.36444
# [219]	validation-rmse:6.36352
# [220]	validation-rmse:6.36347
# [221]	validation-rmse:6.36342
# [222]	validation-rmse:6.36328
# [223]	validation-rmse:6.36306
# [224]	validation-rmse:6.36302
# [225]	validation-rmse:6.36306
# [226]	validation-rmse:6.36277
# [227]	validation-rmse:6.36256
# [228]	validation-rmse:6.36223
# [229]	validation-rmse:6.36225
# [230]	validation-rmse:6.36219
# [231]	validation-rmse:6.36251
# [232]	validation-rmse:6.36257
# [233]	validation-rmse:6.36249
# [234]	validation-rmse:6.36232
# [235]	validation-rmse:6.36229
# [236]	validation-rmse:6.36211
# [237]	validation-rmse:6.36220
# [238]	validation-rmse:6.36204
# [239]	validation-rmse:6.36217
# [240]	validation-rmse:6.36210
# [241]	validation-rmse:6.36193
# [242]	validation-rmse:6.36189
# [243]	validation-rmse:6.36163
# [244]	validation-rmse:6.36147
# [245]	validation-rmse:6.36137
# [246]	validation-rmse:6.36122
# [247]	validation-rmse:6.36044
# [248]	validation-rmse:6.35983
# [249]	validation-rmse:6.35871
# [250]	validation-rmse:6.35880
# [251]	validation-rmse:6.35854
# [252]	validation-rmse:6.35833
# [253]	validation-rmse:6.35834
# [254]	validation-rmse:6.35814
# [255]	validation-rmse:6.35799
# [256]	validation-rmse:6.35826
# [257]	validation-rmse:6.35869
# [258]	validation-rmse:6.35873
# [259]	validation-rmse:6.35879
# [260]	validation-rmse:6.35906
# [261]	validation-rmse:6.35916
# [262]	validation-rmse:6.35886
# [263]	validation-rmse:6.35908
# [264]	validation-rmse:6.35936
# [265]	validation-rmse:6.35930
# [266]	validation-rmse:6.35920
# [267]	validation-rmse:6.35931
# [268]	validation-rmse:6.35917
# [269]	validation-rmse:6.35910
# [270]	validation-rmse:6.35909
# [271]	validation-rmse:6.35939
# [272]	validation-rmse:6.36080
# [273]	validation-rmse:6.36095
# [274]	validation-rmse:6.36074
# [275]	validation-rmse:6.36069
# [276]	validation-rmse:6.36059
# [277]	validation-rmse:6.36049
# [278]	validation-rmse:6.36068
# [279]	validation-rmse:6.35995
# [280]	validation-rmse:6.35991
# [281]	validation-rmse:6.36009
# [282]	validation-rmse:6.36025
# [283]	validation-rmse:6.35988
# [284]	validation-rmse:6.35974
# [285]	validation-rmse:6.35978
# [286]	validation-rmse:6.35939
# [287]	validation-rmse:6.35951
# [288]	validation-rmse:6.35969
# [289]	validation-rmse:6.35995
# [290]	validation-rmse:6.35993
# [291]	validation-rmse:6.36004
# [292]	validation-rmse:6.35997
# [293]	validation-rmse:6.35992
# [294]	validation-rmse:6.36029
# [295]	validation-rmse:6.36017
# [296]	validation-rmse:6.36009
# [297]	validation-rmse:6.35954
# [298]	validation-rmse:6.35969
# [299]	validation-rmse:6.35983
# [300]	validation-rmse:6.35978
# [301]	validation-rmse:6.36022
# [302]	validation-rmse:6.36024
# [303]	validation-rmse:6.36094
# [304]	validation-rmse:6.36121
# [305]	validation-rmse:6.36156

# %% [markdown]
# ### MODEL SELECTION
#
# - RandomForestRegressor
# - GradientBoostingRegressor
# - ExtraTreeRegressor
# - LinearSVR

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

for model_class in tqdm((RandomForestRegressor,
                   GradientBoostingRegressor,
                   ExtraTreesRegressor,
                   LinearSVR), desc="Training..."):
    with mlflow.start_run(run_name="model_selection"):
        
        mlflow.sklearn.autolog()
        mlflow.set_tag("developer", "surawut")
        mlflow.set_tag("model", {model_class()})
        
        mlflow.log_param("train_path", {train_path})
        mlflow.log_param("valid_path", {valid_path})
        mlflow.log_artifact("./mlflow/models/preprocessor.b", artifact_path='preprocessor')
       
        model = model_class()
        model.fit(X_train, y_train)
        
        y_pred = model.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
        
        with open('./mlflow/models/preprocessor.b', 'wb') as dv_out:
            pickle.dump(dv, dv_out)
            
        mlflow.log_artifact('./mlflow/models/preprocessor.b', artifact_path='preprocessor')
# Out:
# Training...: 100%|██████████| 4/4 [27:18<00:00, 409.55s/it]

# %% [markdown]
# ## SELECTED THE BEST MODEL FROM MLFLOW AND EVALUATE MODEL

# %% [markdown]
# ## LOAD MODEL FOR PREDICTION

# %%
logged_model = 'runs:/3cd71efdccd4468f85d0278e8b062bea/models_xgboost'

# %%
loaded_model = mlflow.pyfunc.load_model(logged_model)
loaded_model
# Out:
# [10:49:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_xgboost
#   flavor: mlflow.xgboost
#   run_id: 3cd71efdccd4468f85d0278e8b062bea

# %%
xgboost = mlflow.xgboost.load_model(logged_model)
xgboost
# Out:
# [10:49:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.

# %%
y_pred = xgboost.predict(valid)
y_pred[:10]
# Out:
# array([15.052768,  6.983479, 16.258198, 24.636147,  9.48605 , 17.167553,
#        10.363366,  7.713389,  9.043783, 20.177074], dtype=float32)
