# %% [markdown]
# # MLFLOW EXPERIMENT TRACKING

# %% [markdown]
# ## SET UP ENVIRONMENT

# %%
# !python -V
# Out:
# Python 3.9.12

# %%
import pandas as pd
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## SET UP MLFLOW

# %%
# %%bash

# mlflow ui --backend-store-uri sqlite:///mlflow.db
# Out:
# [2022-06-18 21:37:45 +0700] [47213] [INFO] Starting gunicorn 20.1.0
# [2022-06-18 21:37:45 +0700] [47213] [INFO] Listening at: http://127.0.0.1:5000 (47213)
# [2022-06-18 21:37:45 +0700] [47213] [INFO] Using worker: sync
# [2022-06-18 21:37:45 +0700] [47218] [INFO] Booting worker with pid: 47218
# [2022-06-18 21:38:23 +0700] [47213] [INFO] Handling signal: int
# Error while terminating subprocess (pid=47207):
# [2022-06-18 21:38:23 +0700] [47218] [INFO] Worker exiting (pid: 47218)
#
# Aborted!
# [2022-06-18 21:38:23 +0700] [47213] [INFO] Shutting down: Master

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("trip_prediction-experiment")
# Out:
# <Experiment: artifact_location='./mlruns/6', experiment_id='6', lifecycle_stage='active', name='trip_prediction-experiment', tags={}>

# %% [markdown]
# ## PREPARE DATASET

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df['lpep_dropoff_datetime'] = pd.to_datetime(df['lpep_dropoff_datetime'])
    df['lpep_pickup_datetime'] = pd.to_datetime(df['lpep_pickup_datetime'])

    df['duration'] = df['lpep_dropoff_datetime'] - df['lpep_pickup_datetime']
    df['duration'] = df['duration'].apply(lambda x: x.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
train_path = './data/green_tripdata_2021-01.parquet'
valid_path = './data/green_tripdata_2021-02.parquet'

# %%
df_train = read_dataframe(train_path)
df_val = read_dataframe(valid_path)

# %%
print(f'train_dataset: {len(df_train)}')
print(f'valid_dataset: {len(df_val)}')
# Out:
# train_dataset: 73908
# valid_dataset: 61921

# %% [markdown]
# ## FEATURE ENGINEERING

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %% [markdown]
# from pathlib import Path
#
# model_path = Path('./models/')
# model_path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## MODEL TRAINING AND EXPERIMENT

# %% [markdown]
# ### LINEAR REGRESSION - BASELINE

# %%
with mlflow.start_run(run_name="base_model"):
    
    mlflow.set_tag("developer", "surawut")
    mlflow.set_tag("model", "linear regession")
    
    mlflow.log_param("train_path", {train_path})
    mlflow.log_param("valid_path", {valid_path})
    
    lr = LinearRegression()
    lr.fit(X_train, y_train)
    mlflow.sklearn.log_model(lr, artifact_path="sklearn-model")

    y_pred = lr.predict(X_val)

    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)
    
    with open('./models/linear_regression.bin', 'wb') as f_out:
        pickle.dump(lr, f_out)
        
    with open('./models/preprocessor.b', 'wb') as dv_out:
        pickle.dump(dv, dv_out)
        
    mlflow.log_artifact('./models/linear_regression.bin', artifact_path='models_pickle')
    mlflow.log_artifact('./models/preprocessor.b', artifact_path='preprocessor')

# %% [markdown]
# ### LINEAR REGRESSION - LASSO

# %%
with mlflow.start_run(run_name="model_selection"):
    
    mlflow.set_tag("developer", "surawut")
    mlflow.set_tag("model", "linear regession")
    
    mlflow.log_param("train_path", {train_path})
    mlflow.log_param("valid_path", {valid_path})
    
    
    alpha = 0.1
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)
    
    mlflow.log_param("alpha", alpha)
    mlflow.sklearn.log_model(lr, artifact_path='sklearn_model')
    
    y_pred = lr.predict(X_val)
    
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)
    
    with open('./models/lasso.bin', 'wb') as f_out:
        pickle.dump(lr, f_out)
        
    with open('./models/preprocessor.b', 'wb') as dv_out:
        pickle.dump(dv, dv_out)
        
    mlflow.log_artifact('./models/lasso.bin', artifact_path='models_pickle')
    mlflow.log_artifact('./models/preprocessor.b', artifact_path='preprocessor')

# %% [markdown]
# ### XGBOOST

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %% [markdown]
# ### HYPER OPT FOR FINE TUNING

# %%
def objective(params):
    with mlflow.start_run(run_name="fine tuning"):
        mlflow.set_tag("developer", "surawut")
        mlflow.set_tag("model", "hyperopt")
        mlflow.log_params(params)
        
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
        
    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=10,
    trials=Trials()
)
# Out:
# [21:47:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:18.84759
# [1]	validation-rmse:16.84099
# [2]	validation-rmse:15.12949
# [3]	validation-rmse:13.67865
# [4]	validation-rmse:12.44926
# [5]	validation-rmse:11.41718
# [6]	validation-rmse:10.55411
# [7]	validation-rmse:9.83176
# [8]	validation-rmse:9.23514
# [9]	validation-rmse:8.74410
# [10]	validation-rmse:8.33857
# [11]	validation-rmse:8.00520
# [12]	validation-rmse:7.73236
# [13]	validation-rmse:7.51069
# [14]	validation-rmse:7.32968
# [15]	validation-rmse:7.18104
# [16]	validation-rmse:7.05946
# [17]	validation-rmse:6.96044
# [18]	validation-rmse:6.87649
# [19]	validation-rmse:6.80804
# [20]	validation-rmse:6.75185
# [21]	validation-rmse:6.70400
# [22]	validation-rmse:6.66231
# [23]	validation-rmse:6.62794
# [24]	validation-rmse:6.59977
# [25]	validation-rmse:6.57550
# [26]	validation-rmse:6.55541
# [27]	validation-rmse:6.53720
# [28]	validation-rmse:6.52171
# [29]	validation-rmse:6.50789
# [30]	validation-rmse:6.49716
# [31]	validation-rmse:6.48705
# [32]	validation-rmse:6.47836
# [33]	validation-rmse:6.47064
# [34]	validation-rmse:6.46421
# [35]	validation-rmse:6.45894
# [36]	validation-rmse:6.45435
# [37]	validation-rmse:6.45016
# [38]	validation-rmse:6.44652
# [39]	validation-rmse:6.44295
# [40]	validation-rmse:6.44036
# [41]	validation-rmse:6.43702
# [42]	validation-rmse:6.43461
# [43]	validation-rmse:6.43237
# [44]	validation-rmse:6.43071
# [45]	validation-rmse:6.42908
# [46]	validation-rmse:6.42724
# [47]	validation-rmse:6.42563
# [48]	validation-rmse:6.42352
# [49]	validation-rmse:6.42203
# [50]	validation-rmse:6.42062
# [51]	validation-rmse:6.41862
# [52]	validation-rmse:6.41691
# [53]	validation-rmse:6.41629
# [54]	validation-rmse:6.41478
# [55]	validation-rmse:6.41363
# [56]	validation-rmse:6.41258
# [57]	validation-rmse:6.41068
# [58]	validation-rmse:6.40992
# [59]	validation-rmse:6.40874
# [60]	validation-rmse:6.40777
# [61]	validation-rmse:6.40702
# [62]	validation-rmse:6.40653
# [63]	validation-rmse:6.40537
# [64]	validation-rmse:6.40481
# [65]	validation-rmse:6.40394
# [66]	validation-rmse:6.40296
# [67]	validation-rmse:6.40222
# [68]	validation-rmse:6.40145
# [69]	validation-rmse:6.40010
# [70]	validation-rmse:6.39955
# [71]	validation-rmse:6.39893
# [72]	validation-rmse:6.39824
# [73]	validation-rmse:6.39764
# [74]	validation-rmse:6.39676
# [75]	validation-rmse:6.39577
# [76]	validation-rmse:6.39515
# [77]	validation-rmse:6.39457
# [78]	validation-rmse:6.39408
# [79]	validation-rmse:6.39353
# [80]	validation-rmse:6.39312
# [81]	validation-rmse:6.39236
# [82]	validation-rmse:6.39202
# [83]	validation-rmse:6.39161
# [84]	validation-rmse:6.39131
# [85]	validation-rmse:6.39036
# [86]	validation-rmse:6.38960
# [87]	validation-rmse:6.38952
# [88]	validation-rmse:6.38902
# [89]	validation-rmse:6.38822
# [90]	validation-rmse:6.38767
# [91]	validation-rmse:6.38672
# [92]	validation-rmse:6.38617
# [93]	validation-rmse:6.38571
# [94]	validation-rmse:6.38513
# [95]	validation-rmse:6.38484
# [96]	validation-rmse:6.38396
# [97]	validation-rmse:6.38301
# [98]	validation-rmse:6.38262
# [99]	validation-rmse:6.38229
# [100]	validation-rmse:6.38185
# [101]	validation-rmse:6.38111
# [102]	validation-rmse:6.38070
# [103]	validation-rmse:6.38062
# [104]	validation-rmse:6.38034
# [105]	validation-rmse:6.38006
# [106]	validation-rmse:6.37983
# [107]	validation-rmse:6.37926
# [108]	validation-rmse:6.37883
# [109]	validation-rmse:6.37830
# [110]	validation-rmse:6.37804
# [111]	validation-rmse:6.37761
# [112]	validation-rmse:6.37714
# [113]	validation-rmse:6.37699
# [114]	validation-rmse:6.37663
# [115]	validation-rmse:6.37641
# [116]	validation-rmse:6.37618
# [117]	validation-rmse:6.37561
# [118]	validation-rmse:6.37538
# [119]	validation-rmse:6.37463
# [120]	validation-rmse:6.37437
# [121]	validation-rmse:6.37410
# [122]	validation-rmse:6.37371
# [123]	validation-rmse:6.37320
# [124]	validation-rmse:6.37296
# [125]	validation-rmse:6.37257
# [126]	validation-rmse:6.37221
# [127]	validation-rmse:6.37157
# [128]	validation-rmse:6.37143
# [129]	validation-rmse:6.37118
# [130]	validation-rmse:6.37091
# [131]	validation-rmse:6.37052
# [132]	validation-rmse:6.37015
# [133]	validation-rmse:6.36994
# [134]	validation-rmse:6.36981
# [135]	validation-rmse:6.36946
# [136]	validation-rmse:6.36932
# [137]	validation-rmse:6.36906
# [138]	validation-rmse:6.36878
# [139]	validation-rmse:6.36832
# [140]	validation-rmse:6.36790
# [141]	validation-rmse:6.36768
# [142]	validation-rmse:6.36729
# [143]	validation-rmse:6.36716
# [144]	validation-rmse:6.36686
# [145]	validation-rmse:6.36666
# [146]	validation-rmse:6.36672
# [147]	validation-rmse:6.36644
# [148]	validation-rmse:6.36608
# [149]	validation-rmse:6.36598
# [150]	validation-rmse:6.36574
# [151]	validation-rmse:6.36519
# [152]	validation-rmse:6.36512
# [153]	validation-rmse:6.36459
# [154]	validation-rmse:6.36426
# [155]	validation-rmse:6.36397
# [156]	validation-rmse:6.36366
# [157]	validation-rmse:6.36354
# [158]	validation-rmse:6.36342
# [159]	validation-rmse:6.36280
# [160]	validation-rmse:6.36251
# [161]	validation-rmse:6.36185
# [162]	validation-rmse:6.36156
# [163]	validation-rmse:6.36114
# [164]	validation-rmse:6.36089
# [165]	validation-rmse:6.36054
# [166]	validation-rmse:6.36042
# [167]	validation-rmse:6.36017
# [168]	validation-rmse:6.35981
# [169]	validation-rmse:6.35975
# [170]	validation-rmse:6.35967
# [171]	validation-rmse:6.35921
# [172]	validation-rmse:6.35915
# [173]	validation-rmse:6.35913
# [174]	validation-rmse:6.35891
# [175]	validation-rmse:6.35849
# [176]	validation-rmse:6.35834
# [177]	validation-rmse:6.35829
# [178]	validation-rmse:6.35803
# [179]	validation-rmse:6.35741
# [180]	validation-rmse:6.35726
# [181]	validation-rmse:6.35710
# [182]	validation-rmse:6.35701
# [183]	validation-rmse:6.35704
# [184]	validation-rmse:6.35684
# [185]	validation-rmse:6.35673
# [186]	validation-rmse:6.35650
# [187]	validation-rmse:6.35615
# [188]	validation-rmse:6.35626
# [189]	validation-rmse:6.35638
# [190]	validation-rmse:6.35626
# [191]	validation-rmse:6.35606
# [192]	validation-rmse:6.35597
# [193]	validation-rmse:6.35587
# [194]	validation-rmse:6.35553
# [195]	validation-rmse:6.35560
# [196]	validation-rmse:6.35561
# [197]	validation-rmse:6.35576
# [198]	validation-rmse:6.35553
# [199]	validation-rmse:6.35520
# [200]	validation-rmse:6.35514
# [201]	validation-rmse:6.35521
# [202]	validation-rmse:6.35492
# [203]	validation-rmse:6.35469
# [204]	validation-rmse:6.35479
# [205]	validation-rmse:6.35402
# [206]	validation-rmse:6.35373
# [207]	validation-rmse:6.35361
# [208]	validation-rmse:6.35366
# [209]	validation-rmse:6.35358
# [210]	validation-rmse:6.35309
# [211]	validation-rmse:6.35264
# [212]	validation-rmse:6.35252
# [213]	validation-rmse:6.35241
# [214]	validation-rmse:6.35212
# [215]	validation-rmse:6.35203
# [216]	validation-rmse:6.35161
# [217]	validation-rmse:6.35154
# [218]	validation-rmse:6.35196
# [219]	validation-rmse:6.35212
# [220]	validation-rmse:6.35221
# [221]	validation-rmse:6.35215
# [222]	validation-rmse:6.35232
# [223]	validation-rmse:6.35225
# [224]	validation-rmse:6.35203
# [225]	validation-rmse:6.35171
# [226]	validation-rmse:6.35131
# [227]	validation-rmse:6.35118
# [228]	validation-rmse:6.35120
# [229]	validation-rmse:6.35119
# [230]	validation-rmse:6.35118
# [231]	validation-rmse:6.35108
# [232]	validation-rmse:6.35086
# [233]	validation-rmse:6.35097
# [234]	validation-rmse:6.35088
# [235]	validation-rmse:6.35062
# [236]	validation-rmse:6.35071
# [237]	validation-rmse:6.35085
# [238]	validation-rmse:6.35052
# [239]	validation-rmse:6.35033
# [240]	validation-rmse:6.35034
# [241]	validation-rmse:6.35026
# [242]	validation-rmse:6.35054
# [243]	validation-rmse:6.35040
# [244]	validation-rmse:6.35015
# [245]	validation-rmse:6.35000
# [246]	validation-rmse:6.34974
# [247]	validation-rmse:6.34962
# [248]	validation-rmse:6.34954
# [249]	validation-rmse:6.34965
# [250]	validation-rmse:6.34948
# [251]	validation-rmse:6.34953
# [252]	validation-rmse:6.34954
# [253]	validation-rmse:6.34943
# [254]	validation-rmse:6.34925
# [255]	validation-rmse:6.34911
# [256]	validation-rmse:6.34944
# [257]	validation-rmse:6.34951
# [258]	validation-rmse:6.35024
# [259]	validation-rmse:6.34990
# [260]	validation-rmse:6.34982
# [261]	validation-rmse:6.35027
# [262]	validation-rmse:6.35035
# [263]	validation-rmse:6.35021
# [264]	validation-rmse:6.34991
# [265]	validation-rmse:6.35002
# [266]	validation-rmse:6.34987
# [267]	validation-rmse:6.34976
# [268]	validation-rmse:6.34959
# [269]	validation-rmse:6.34955
# [270]	validation-rmse:6.34971
# [271]	validation-rmse:6.35005
# [272]	validation-rmse:6.34987
# [273]	validation-rmse:6.34946
# [274]	validation-rmse:6.34927
# [275]	validation-rmse:6.34923
# [276]	validation-rmse:6.34958
# [277]	validation-rmse:6.34950
# [278]	validation-rmse:6.34948
# [279]	validation-rmse:6.34924
# [280]	validation-rmse:6.34925
# [281]	validation-rmse:6.34905
# [282]	validation-rmse:6.34917
# [283]	validation-rmse:6.34926
# [284]	validation-rmse:6.34979
# [285]	validation-rmse:6.35025
# [286]	validation-rmse:6.35033
# [287]	validation-rmse:6.35013
# [288]	validation-rmse:6.35015
# [289]	validation-rmse:6.35011
# [290]	validation-rmse:6.34997
# [291]	validation-rmse:6.34995
# [292]	validation-rmse:6.34987
# [293]	validation-rmse:6.34965
# [294]	validation-rmse:6.34962
# [295]	validation-rmse:6.34933
# [296]	validation-rmse:6.34911
# [297]	validation-rmse:6.34908
# [298]	validation-rmse:6.34903
# [299]	validation-rmse:6.34897
# [300]	validation-rmse:6.34877
# [301]	validation-rmse:6.34860
# [302]	validation-rmse:6.34870
# [303]	validation-rmse:6.34844
# [304]	validation-rmse:6.34843
# [305]	validation-rmse:6.34920
# [306]	validation-rmse:6.34918
# [307]	validation-rmse:6.34965
# [308]	validation-rmse:6.34978
# [309]	validation-rmse:6.34989
# [310]	validation-rmse:6.35006
# [311]	validation-rmse:6.35012
# [312]	validation-rmse:6.35024
# [313]	validation-rmse:6.35017
# [314]	validation-rmse:6.34992
# [315]	validation-rmse:6.34971
# [316]	validation-rmse:6.34993
# [317]	validation-rmse:6.34991
# [318]	validation-rmse:6.35018
# [319]	validation-rmse:6.35005
# [320]	validation-rmse:6.35017
# [321]	validation-rmse:6.35012
# [322]	validation-rmse:6.35023
# [323]	validation-rmse:6.35023
# [324]	validation-rmse:6.35014
# [325]	validation-rmse:6.35008
# [326]	validation-rmse:6.34992
# [327]	validation-rmse:6.34984
# [328]	validation-rmse:6.34972
# [329]	validation-rmse:6.34963
# [330]	validation-rmse:6.34960
# [331]	validation-rmse:6.34948
# [332]	validation-rmse:6.34922
# [333]	validation-rmse:6.34933
# [334]	validation-rmse:6.34931
# [335]	validation-rmse:6.34945
# [336]	validation-rmse:6.34979
# [337]	validation-rmse:6.34970
# [338]	validation-rmse:6.34981
# [339]	validation-rmse:6.35067
# [340]	validation-rmse:6.35073
# [341]	validation-rmse:6.35088
# [342]	validation-rmse:6.35104
# [343]	validation-rmse:6.35126
# [344]	validation-rmse:6.35118
# [345]	validation-rmse:6.35126
# [346]	validation-rmse:6.35127
# [347]	validation-rmse:6.35129
# [348]	validation-rmse:6.35089
# [349]	validation-rmse:6.35080
# [350]	validation-rmse:6.35072
# [351]	validation-rmse:6.35034
# [352]	validation-rmse:6.35095
# [353]	validation-rmse:6.35109
# [354]	validation-rmse:6.35109
# [21:47:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:16.95851
# [1]	validation-rmse:13.85689
# [2]	validation-rmse:11.62121
# [3]	validation-rmse:10.04278
# [4]	validation-rmse:8.94830
# [5]	validation-rmse:8.19919
# [6]	validation-rmse:7.69537
# [7]	validation-rmse:7.35778
# [8]	validation-rmse:7.13155
# [9]	validation-rmse:6.97644
# [10]	validation-rmse:6.87055
# [11]	validation-rmse:6.79435
# [12]	validation-rmse:6.73935
# [13]	validation-rmse:6.70181
# [14]	validation-rmse:6.67393
# [15]	validation-rmse:6.65250
# [16]	validation-rmse:6.63715
# [17]	validation-rmse:6.62425
# [18]	validation-rmse:6.61572
# [19]	validation-rmse:6.60958
# [20]	validation-rmse:6.60522
# [21]	validation-rmse:6.59875
# [22]	validation-rmse:6.59510
# [23]	validation-rmse:6.59120
# [24]	validation-rmse:6.58851
# [25]	validation-rmse:6.58657
# [26]	validation-rmse:6.58410
# [27]	validation-rmse:6.58121
# [28]	validation-rmse:6.57852
# [29]	validation-rmse:6.57612
# [30]	validation-rmse:6.57385
# [31]	validation-rmse:6.57305
# [32]	validation-rmse:6.57090
# [33]	validation-rmse:6.56904
# [34]	validation-rmse:6.56730
# [35]	validation-rmse:6.56600
# [36]	validation-rmse:6.56497
# [37]	validation-rmse:6.56357
# [38]	validation-rmse:6.56230
# [39]	validation-rmse:6.56108
# [40]	validation-rmse:6.55917
# [41]	validation-rmse:6.55802
# [42]	validation-rmse:6.55680
# [43]	validation-rmse:6.55604
# [44]	validation-rmse:6.55467
# [45]	validation-rmse:6.55375
# [46]	validation-rmse:6.55233
# [47]	validation-rmse:6.55108
# [48]	validation-rmse:6.54807
# [49]	validation-rmse:6.54699
# [50]	validation-rmse:6.54530
# [51]	validation-rmse:6.54420
# [52]	validation-rmse:6.54307
# [53]	validation-rmse:6.54247
# [54]	validation-rmse:6.54188
# [55]	validation-rmse:6.54060
# [56]	validation-rmse:6.53935
# [57]	validation-rmse:6.53778
# [58]	validation-rmse:6.53649
# [59]	validation-rmse:6.53530
# [60]	validation-rmse:6.53428
# [61]	validation-rmse:6.53350
# [62]	validation-rmse:6.53272
# [63]	validation-rmse:6.53192
# [64]	validation-rmse:6.53144
# [65]	validation-rmse:6.52857
# [66]	validation-rmse:6.52801
# [67]	validation-rmse:6.52693
# [68]	validation-rmse:6.52573
# [69]	validation-rmse:6.52524
# [70]	validation-rmse:6.52467
# [71]	validation-rmse:6.52373
# [72]	validation-rmse:6.52321
# [73]	validation-rmse:6.52171
# [74]	validation-rmse:6.52134
# [75]	validation-rmse:6.51951
# [76]	validation-rmse:6.51828
# [77]	validation-rmse:6.51753
# [78]	validation-rmse:6.51664
# [79]	validation-rmse:6.51606
# [80]	validation-rmse:6.51514
# [81]	validation-rmse:6.51443
# [82]	validation-rmse:6.51395
# [83]	validation-rmse:6.51366
# [84]	validation-rmse:6.51292
# [85]	validation-rmse:6.51208
# [86]	validation-rmse:6.51161
# [87]	validation-rmse:6.51113
# [88]	validation-rmse:6.51035
# [89]	validation-rmse:6.50951
# [90]	validation-rmse:6.50883
# [91]	validation-rmse:6.50813
# [92]	validation-rmse:6.50743
# [93]	validation-rmse:6.50702
# [94]	validation-rmse:6.50615
# [95]	validation-rmse:6.50517
# [96]	validation-rmse:6.50407
# [97]	validation-rmse:6.50317
# [98]	validation-rmse:6.50241
# [99]	validation-rmse:6.50044
# [100]	validation-rmse:6.50009
# [101]	validation-rmse:6.49956
# [102]	validation-rmse:6.49933
# [103]	validation-rmse:6.49820
# [104]	validation-rmse:6.49772
# [105]	validation-rmse:6.49714
# [106]	validation-rmse:6.49665
# [107]	validation-rmse:6.49605
# [108]	validation-rmse:6.49521
# [109]	validation-rmse:6.49468
# [110]	validation-rmse:6.49463
# [111]	validation-rmse:6.49435
# [112]	validation-rmse:6.49393
# [113]	validation-rmse:6.49333
# [114]	validation-rmse:6.49287
# [115]	validation-rmse:6.49202
# [116]	validation-rmse:6.49187
# [117]	validation-rmse:6.49137
# [118]	validation-rmse:6.49077
# [119]	validation-rmse:6.48981
# [120]	validation-rmse:6.48925
# [121]	validation-rmse:6.48866
# [122]	validation-rmse:6.48825
# [123]	validation-rmse:6.48790
# [124]	validation-rmse:6.48741
# [125]	validation-rmse:6.48671
# [126]	validation-rmse:6.48610
# [127]	validation-rmse:6.48572
# [128]	validation-rmse:6.48526
# [129]	validation-rmse:6.48472
# [130]	validation-rmse:6.48409
# [131]	validation-rmse:6.48356
# [132]	validation-rmse:6.48312
# [133]	validation-rmse:6.48274
# [134]	validation-rmse:6.48225
# [135]	validation-rmse:6.48175
# [136]	validation-rmse:6.48120
# [137]	validation-rmse:6.47989
# [138]	validation-rmse:6.47972
# [139]	validation-rmse:6.47944
# [140]	validation-rmse:6.47908
# [141]	validation-rmse:6.47872
# [142]	validation-rmse:6.47820
# [143]	validation-rmse:6.47801
# [144]	validation-rmse:6.47772
# [145]	validation-rmse:6.47737
# [146]	validation-rmse:6.47679
# [147]	validation-rmse:6.47643
# [148]	validation-rmse:6.47618
# [149]	validation-rmse:6.47579
# [150]	validation-rmse:6.47562
# [151]	validation-rmse:6.47506
# [152]	validation-rmse:6.47488
# [153]	validation-rmse:6.47445
# [154]	validation-rmse:6.47420
# [155]	validation-rmse:6.47389
# [156]	validation-rmse:6.47357
# [157]	validation-rmse:6.47317
# [158]	validation-rmse:6.47274
# [159]	validation-rmse:6.47240
# [160]	validation-rmse:6.47161
# [161]	validation-rmse:6.47115
# [162]	validation-rmse:6.47084
# [163]	validation-rmse:6.47031
# [164]	validation-rmse:6.46995
# [165]	validation-rmse:6.46959
# [166]	validation-rmse:6.46924
# [167]	validation-rmse:6.46888
# [168]	validation-rmse:6.46860
# [169]	validation-rmse:6.46853
# [170]	validation-rmse:6.46853
# [171]	validation-rmse:6.46835
# [172]	validation-rmse:6.46806
# [173]	validation-rmse:6.46797
# [174]	validation-rmse:6.46765
# [175]	validation-rmse:6.46679
# [176]	validation-rmse:6.46639
# [177]	validation-rmse:6.46587
# [178]	validation-rmse:6.46563
# [179]	validation-rmse:6.46557
# [180]	validation-rmse:6.46534
# [181]	validation-rmse:6.46543
# [182]	validation-rmse:6.46490
# [183]	validation-rmse:6.46465
# [184]	validation-rmse:6.46430
# [185]	validation-rmse:6.46431
# [186]	validation-rmse:6.46385
# [187]	validation-rmse:6.46357
# [188]	validation-rmse:6.46326
# [189]	validation-rmse:6.46297
# [190]	validation-rmse:6.46252
# [191]	validation-rmse:6.46224
# [192]	validation-rmse:6.46169
# [193]	validation-rmse:6.46138
# [194]	validation-rmse:6.46133
# [195]	validation-rmse:6.46095
# [196]	validation-rmse:6.46056
# [197]	validation-rmse:6.46038
# [198]	validation-rmse:6.46036
# [199]	validation-rmse:6.46039
# [200]	validation-rmse:6.46004
# [201]	validation-rmse:6.45973
# [202]	validation-rmse:6.45951
# [203]	validation-rmse:6.45917
# [204]	validation-rmse:6.45879
# [205]	validation-rmse:6.45826
# [206]	validation-rmse:6.45810
# [207]	validation-rmse:6.45786
# [208]	validation-rmse:6.45747
# [209]	validation-rmse:6.45721
# [210]	validation-rmse:6.45668
# [211]	validation-rmse:6.45633
# [212]	validation-rmse:6.45609
# [213]	validation-rmse:6.45577
# [214]	validation-rmse:6.45518
# [215]	validation-rmse:6.45483
# [216]	validation-rmse:6.45472
# [217]	validation-rmse:6.45448
# [218]	validation-rmse:6.45422
# [219]	validation-rmse:6.45374
# [220]	validation-rmse:6.45344
# [221]	validation-rmse:6.45332
# [222]	validation-rmse:6.45326
# [223]	validation-rmse:6.45311
# [224]	validation-rmse:6.45298
# [225]	validation-rmse:6.45277
# [226]	validation-rmse:6.45266
# [227]	validation-rmse:6.45239
# [228]	validation-rmse:6.45191
# [229]	validation-rmse:6.45110
# [230]	validation-rmse:6.45082
# [231]	validation-rmse:6.45002
# [232]	validation-rmse:6.44979
# [233]	validation-rmse:6.44968
# [234]	validation-rmse:6.44947
# [235]	validation-rmse:6.44926
# [236]	validation-rmse:6.44901
# [237]	validation-rmse:6.44898
# [238]	validation-rmse:6.44878
# [239]	validation-rmse:6.44866
# [240]	validation-rmse:6.44844
# [241]	validation-rmse:6.44794
# [242]	validation-rmse:6.44774
# [243]	validation-rmse:6.44756
# [244]	validation-rmse:6.44750
# [245]	validation-rmse:6.44761
# [246]	validation-rmse:6.44751
# [247]	validation-rmse:6.44730
# [248]	validation-rmse:6.44708
# [249]	validation-rmse:6.44685
# [250]	validation-rmse:6.44658
# [251]	validation-rmse:6.44641
# [252]	validation-rmse:6.44618
# [253]	validation-rmse:6.44568
# [254]	validation-rmse:6.44554
# [255]	validation-rmse:6.44498
# [256]	validation-rmse:6.44465
# [257]	validation-rmse:6.44442
# [258]	validation-rmse:6.44363
# [259]	validation-rmse:6.44367
# [260]	validation-rmse:6.44347
# [261]	validation-rmse:6.44309
# [262]	validation-rmse:6.44312
# [263]	validation-rmse:6.44283
# [264]	validation-rmse:6.44267
# [265]	validation-rmse:6.44212
# [266]	validation-rmse:6.44190
# [267]	validation-rmse:6.44169
# [268]	validation-rmse:6.44149
# [269]	validation-rmse:6.44127
# [270]	validation-rmse:6.44108
# [271]	validation-rmse:6.44112
# [272]	validation-rmse:6.44084
# [273]	validation-rmse:6.44080
# [274]	validation-rmse:6.44071
# [275]	validation-rmse:6.44055
# [276]	validation-rmse:6.44048
# [277]	validation-rmse:6.44040
# [278]	validation-rmse:6.44028
# [279]	validation-rmse:6.44006
# [280]	validation-rmse:6.43998
# [281]	validation-rmse:6.43942
# [282]	validation-rmse:6.43861
# [283]	validation-rmse:6.43849
# [284]	validation-rmse:6.43853
# [285]	validation-rmse:6.43802
# [286]	validation-rmse:6.43790
# [287]	validation-rmse:6.43795
# [288]	validation-rmse:6.43772
# [289]	validation-rmse:6.43762
# [290]	validation-rmse:6.43745
# [291]	validation-rmse:6.43724
# [292]	validation-rmse:6.43702
# [293]	validation-rmse:6.43691
# [294]	validation-rmse:6.43687
# [295]	validation-rmse:6.43643
# [296]	validation-rmse:6.43623
# [297]	validation-rmse:6.43619
# [298]	validation-rmse:6.43632
# [299]	validation-rmse:6.43599
# [300]	validation-rmse:6.43590
# [301]	validation-rmse:6.43584
# [302]	validation-rmse:6.43555
# [303]	validation-rmse:6.43546
# [304]	validation-rmse:6.43545
# [305]	validation-rmse:6.43535
# [306]	validation-rmse:6.43517
# [307]	validation-rmse:6.43509
# [308]	validation-rmse:6.43494
# [309]	validation-rmse:6.43490
# [310]	validation-rmse:6.43479
# [311]	validation-rmse:6.43468
# [312]	validation-rmse:6.43441
# [313]	validation-rmse:6.43418
# [314]	validation-rmse:6.43386
# [315]	validation-rmse:6.43374
# [316]	validation-rmse:6.43359
# [317]	validation-rmse:6.43355
# [318]	validation-rmse:6.43341
# [319]	validation-rmse:6.43344
# [320]	validation-rmse:6.43341
# [321]	validation-rmse:6.43317
# [322]	validation-rmse:6.43312
# [323]	validation-rmse:6.43301
# [324]	validation-rmse:6.43293
# [325]	validation-rmse:6.43258
# [326]	validation-rmse:6.43237
# [327]	validation-rmse:6.43222
# [328]	validation-rmse:6.43211
# [329]	validation-rmse:6.43198
# [330]	validation-rmse:6.43176
# [331]	validation-rmse:6.43167
# [332]	validation-rmse:6.43150
# [333]	validation-rmse:6.43143
# [334]	validation-rmse:6.43141
# [335]	validation-rmse:6.43113
# [336]	validation-rmse:6.43111
# [337]	validation-rmse:6.43090
# [338]	validation-rmse:6.43091
# [339]	validation-rmse:6.43086
# [340]	validation-rmse:6.43120
# [341]	validation-rmse:6.43099
# [342]	validation-rmse:6.43081
# [343]	validation-rmse:6.43066
# [344]	validation-rmse:6.43061
# [345]	validation-rmse:6.43072
# [346]	validation-rmse:6.43079
# [347]	validation-rmse:6.43072
# [348]	validation-rmse:6.43067
# [349]	validation-rmse:6.43034
# ...
# [42]	validation-rmse:6.45119
# [43]	validation-rmse:6.45116
# [44]	validation-rmse:6.45149
# [45]	validation-rmse:6.45239
# [46]	validation-rmse:6.45077
# [47]	validation-rmse:6.45112
# [48]	validation-rmse:6.45273
# [49]	validation-rmse:6.45056
# [50]	validation-rmse:6.45135
# [51]	validation-rmse:6.44975
# [52]	validation-rmse:6.44982
# [53]	validation-rmse:6.45069
# [54]	validation-rmse:6.45028
# [55]	validation-rmse:6.45173
# [56]	validation-rmse:6.45151
# [57]	validation-rmse:6.45243
# [58]	validation-rmse:6.45338
# [59]	validation-rmse:6.45302
# [60]	validation-rmse:6.45236
# [61]	validation-rmse:6.45200
# [62]	validation-rmse:6.45152
# [63]	validation-rmse:6.45200
# [64]	validation-rmse:6.45425
# [65]	validation-rmse:6.45451
# [66]	validation-rmse:6.46053
# [67]	validation-rmse:6.46147
# [68]	validation-rmse:6.46048
# [69]	validation-rmse:6.46187
# [70]	validation-rmse:6.46167
# [71]	validation-rmse:6.46031
# [72]	validation-rmse:6.45884
# [73]	validation-rmse:6.45905
# [74]	validation-rmse:6.45845
# [75]	validation-rmse:6.45856
# [76]	validation-rmse:6.45942
# [77]	validation-rmse:6.46029
# [78]	validation-rmse:6.45983
# [79]	validation-rmse:6.45949
# [80]	validation-rmse:6.45869
# [81]	validation-rmse:6.45844
# [82]	validation-rmse:6.45945
# [83]	validation-rmse:6.46003
# [84]	validation-rmse:6.45968
# [85]	validation-rmse:6.46031
# [86]	validation-rmse:6.46146
# [87]	validation-rmse:6.46256
# [88]	validation-rmse:6.46184
# [89]	validation-rmse:6.46175
# [90]	validation-rmse:6.46232
# [91]	validation-rmse:6.46189
# [92]	validation-rmse:6.46135
# [93]	validation-rmse:6.47024
# [94]	validation-rmse:6.47120
# [95]	validation-rmse:6.47110
# [96]	validation-rmse:6.47177
# [97]	validation-rmse:6.47218
# [98]	validation-rmse:6.47221
# [99]	validation-rmse:6.47221
# [100]	validation-rmse:6.47299
# [21:52:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:12.32221
# [1]	validation-rmse:8.71042
# [2]	validation-rmse:7.39868
# [3]	validation-rmse:6.92719
# [4]	validation-rmse:6.74726
# [5]	validation-rmse:6.66332
# [6]	validation-rmse:6.62394
# [7]	validation-rmse:6.60117
# [8]	validation-rmse:6.58819
# [9]	validation-rmse:6.58225
# [10]	validation-rmse:6.57365
# [11]	validation-rmse:6.56909
# [12]	validation-rmse:6.56353
# [13]	validation-rmse:6.56140
# [14]	validation-rmse:6.55486
# [15]	validation-rmse:6.55145
# [16]	validation-rmse:6.54820
# [17]	validation-rmse:6.54487
# [18]	validation-rmse:6.54249
# [19]	validation-rmse:6.53673
# [20]	validation-rmse:6.53500
# [21]	validation-rmse:6.53364
# [22]	validation-rmse:6.53286
# [23]	validation-rmse:6.53125
# [24]	validation-rmse:6.52766
# [25]	validation-rmse:6.52672
# [26]	validation-rmse:6.52460
# [27]	validation-rmse:6.52184
# [28]	validation-rmse:6.52040
# [29]	validation-rmse:6.51955
# [30]	validation-rmse:6.51972
# [31]	validation-rmse:6.51930
# [32]	validation-rmse:6.51765
# [33]	validation-rmse:6.51623
# [34]	validation-rmse:6.51673
# [35]	validation-rmse:6.51619
# [36]	validation-rmse:6.51512
# [37]	validation-rmse:6.51535
# [38]	validation-rmse:6.51472
# [39]	validation-rmse:6.51279
# [40]	validation-rmse:6.51221
# [41]	validation-rmse:6.51112
# [42]	validation-rmse:6.51042
# [43]	validation-rmse:6.51037
# [44]	validation-rmse:6.50798
# [45]	validation-rmse:6.50753
# [46]	validation-rmse:6.50715
# [47]	validation-rmse:6.50676
# [48]	validation-rmse:6.50658
# [49]	validation-rmse:6.50615
# [50]	validation-rmse:6.50603
# [51]	validation-rmse:6.50617
# [52]	validation-rmse:6.50989
# [53]	validation-rmse:6.50823
# [54]	validation-rmse:6.50924
# [55]	validation-rmse:6.50877
# [56]	validation-rmse:6.50695
# [57]	validation-rmse:6.50630
# [58]	validation-rmse:6.50611
# [59]	validation-rmse:6.50581
# [60]	validation-rmse:6.50538
# [61]	validation-rmse:6.50353
# [62]	validation-rmse:6.50323
# [63]	validation-rmse:6.50247
# [64]	validation-rmse:6.50127
# [65]	validation-rmse:6.50142
# [66]	validation-rmse:6.50185
# [67]	validation-rmse:6.50198
# [68]	validation-rmse:6.50180
# [69]	validation-rmse:6.50189
# [70]	validation-rmse:6.50181
# [71]	validation-rmse:6.50074
# [72]	validation-rmse:6.50245
# [73]	validation-rmse:6.50186
# [74]	validation-rmse:6.50241
# [75]	validation-rmse:6.50255
# [76]	validation-rmse:6.50122
# [77]	validation-rmse:6.50155
# [78]	validation-rmse:6.50099
# [79]	validation-rmse:6.50201
# [80]	validation-rmse:6.50188
# [81]	validation-rmse:6.50049
# [82]	validation-rmse:6.50036
# [83]	validation-rmse:6.50116
# [84]	validation-rmse:6.50089
# [85]	validation-rmse:6.50095
# [86]	validation-rmse:6.49996
# [87]	validation-rmse:6.50032
# [88]	validation-rmse:6.50083
# [89]	validation-rmse:6.50225
# [90]	validation-rmse:6.50235
# [91]	validation-rmse:6.50423
# [92]	validation-rmse:6.50340
# [93]	validation-rmse:6.50429
# [94]	validation-rmse:6.50456
# [95]	validation-rmse:6.50523
# [96]	validation-rmse:6.50530
# [97]	validation-rmse:6.50560
# [98]	validation-rmse:6.50477
# [99]	validation-rmse:6.50402
# [100]	validation-rmse:6.50425
# [101]	validation-rmse:6.50521
# [102]	validation-rmse:6.50564
# [103]	validation-rmse:6.50527
# [104]	validation-rmse:6.50503
# [105]	validation-rmse:6.50554
# [106]	validation-rmse:6.50570
# [107]	validation-rmse:6.50709
# [108]	validation-rmse:6.50772
# [109]	validation-rmse:6.50766
# [110]	validation-rmse:6.50966
# [111]	validation-rmse:6.51014
# [112]	validation-rmse:6.51014
# [113]	validation-rmse:6.51145
# [114]	validation-rmse:6.51157
# [115]	validation-rmse:6.51171
# [116]	validation-rmse:6.51212
# [117]	validation-rmse:6.51202
# [118]	validation-rmse:6.51271
# [119]	validation-rmse:6.51345
# [120]	validation-rmse:6.51416
# [121]	validation-rmse:6.51549
# [122]	validation-rmse:6.51572
# [123]	validation-rmse:6.51575
# [124]	validation-rmse:6.51628
# [125]	validation-rmse:6.51667
# [126]	validation-rmse:6.51680
# [127]	validation-rmse:6.51846
# [128]	validation-rmse:6.51873
# [129]	validation-rmse:6.51896
# [130]	validation-rmse:6.51972
# [131]	validation-rmse:6.51973
# [132]	validation-rmse:6.52062
# [133]	validation-rmse:6.52072
# [134]	validation-rmse:6.52101
# [135]	validation-rmse:6.52153
# [136]	validation-rmse:6.52210
# 100%|██████████| 10/10 [05:51<00:00, 35.15s/trial, best loss: 6.351087504233244]

# %% [markdown]
# ### XGBOOST OPTIMIZATION HYPER PARAMETER WITH HYPEROPT

# %%
with mlflow.start_run(run_name="tuned_hyper_params"):
    
    mlflow.xgboost.autolog(disable=True)
    mlflow.set_tag("developer", "surawut")
    mlflow.set_tag("model", "xgboost")
    
    best_params = {
        'learning_rate': 0.130837160621154,
        'max_depth': 78,
        'min_child_weight': 1.2331058504757806,
        'objective': 'reg:linear',
        'reg_alpha': 0.12390743789664009,
        'reg_lambda': 0.20084334664548684,
        'seed': 42
    }
    
    mlflow.log_params(best_params)
    
    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )
    
    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)
    
    with open('./models/preprocessor.b', 'wb') as dv_out:
        pickle.dump(dv, dv_out)
        
    with open('./models/xgboost.bin', 'wb') as f_out:
        pickle.dump(booster, f_out)
        
    mlflow.log_artifact('./models/xgboost.bin', artifact_path='models_pickle')
    mlflow.log_artifact('./models/preprocessor.b', artifact_path='preprocessor')
    
    mlflow.xgboost.log_model(booster, artifact_path='models_xgboost')
# Out:
# [21:55:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:18.84759
# [1]	validation-rmse:16.84099
# [2]	validation-rmse:15.12949
# [3]	validation-rmse:13.67865
# [4]	validation-rmse:12.44926
# [5]	validation-rmse:11.41718
# [6]	validation-rmse:10.55411
# [7]	validation-rmse:9.83176
# [8]	validation-rmse:9.23514
# [9]	validation-rmse:8.74410
# [10]	validation-rmse:8.33857
# [11]	validation-rmse:8.00520
# [12]	validation-rmse:7.73236
# [13]	validation-rmse:7.51069
# [14]	validation-rmse:7.32968
# [15]	validation-rmse:7.18104
# [16]	validation-rmse:7.05946
# [17]	validation-rmse:6.96044
# [18]	validation-rmse:6.87649
# [19]	validation-rmse:6.80804
# [20]	validation-rmse:6.75185
# [21]	validation-rmse:6.70400
# [22]	validation-rmse:6.66231
# [23]	validation-rmse:6.62794
# [24]	validation-rmse:6.59977
# [25]	validation-rmse:6.57550
# [26]	validation-rmse:6.55541
# [27]	validation-rmse:6.53720
# [28]	validation-rmse:6.52171
# [29]	validation-rmse:6.50789
# [30]	validation-rmse:6.49716
# [31]	validation-rmse:6.48705
# [32]	validation-rmse:6.47836
# [33]	validation-rmse:6.47064
# [34]	validation-rmse:6.46421
# [35]	validation-rmse:6.45894
# [36]	validation-rmse:6.45435
# [37]	validation-rmse:6.45016
# [38]	validation-rmse:6.44652
# [39]	validation-rmse:6.44295
# [40]	validation-rmse:6.44036
# [41]	validation-rmse:6.43702
# [42]	validation-rmse:6.43461
# [43]	validation-rmse:6.43237
# [44]	validation-rmse:6.43071
# [45]	validation-rmse:6.42908
# [46]	validation-rmse:6.42724
# [47]	validation-rmse:6.42563
# [48]	validation-rmse:6.42352
# [49]	validation-rmse:6.42203
# [50]	validation-rmse:6.42062
# [51]	validation-rmse:6.41862
# [52]	validation-rmse:6.41691
# [53]	validation-rmse:6.41629
# [54]	validation-rmse:6.41478
# [55]	validation-rmse:6.41363
# [56]	validation-rmse:6.41258
# [57]	validation-rmse:6.41068
# [58]	validation-rmse:6.40992
# [59]	validation-rmse:6.40874
# [60]	validation-rmse:6.40777
# [61]	validation-rmse:6.40702
# [62]	validation-rmse:6.40653
# [63]	validation-rmse:6.40537
# [64]	validation-rmse:6.40481
# [65]	validation-rmse:6.40394
# [66]	validation-rmse:6.40296
# [67]	validation-rmse:6.40222
# [68]	validation-rmse:6.40145
# [69]	validation-rmse:6.40010
# [70]	validation-rmse:6.39955
# [71]	validation-rmse:6.39893
# [72]	validation-rmse:6.39824
# [73]	validation-rmse:6.39764
# [74]	validation-rmse:6.39676
# [75]	validation-rmse:6.39577
# [76]	validation-rmse:6.39515
# [77]	validation-rmse:6.39457
# [78]	validation-rmse:6.39408
# [79]	validation-rmse:6.39353
# [80]	validation-rmse:6.39312
# [81]	validation-rmse:6.39236
# [82]	validation-rmse:6.39202
# [83]	validation-rmse:6.39161
# [84]	validation-rmse:6.39131
# [85]	validation-rmse:6.39036
# [86]	validation-rmse:6.38960
# [87]	validation-rmse:6.38952
# [88]	validation-rmse:6.38902
# [89]	validation-rmse:6.38822
# [90]	validation-rmse:6.38767
# [91]	validation-rmse:6.38672
# [92]	validation-rmse:6.38617
# [93]	validation-rmse:6.38571
# [94]	validation-rmse:6.38513
# [95]	validation-rmse:6.38484
# [96]	validation-rmse:6.38396
# [97]	validation-rmse:6.38301
# [98]	validation-rmse:6.38262
# [99]	validation-rmse:6.38229
# [100]	validation-rmse:6.38185
# [101]	validation-rmse:6.38111
# [102]	validation-rmse:6.38070
# [103]	validation-rmse:6.38062
# [104]	validation-rmse:6.38034
# [105]	validation-rmse:6.38006
# [106]	validation-rmse:6.37983
# [107]	validation-rmse:6.37926
# [108]	validation-rmse:6.37883
# [109]	validation-rmse:6.37830
# [110]	validation-rmse:6.37804
# [111]	validation-rmse:6.37761
# [112]	validation-rmse:6.37714
# [113]	validation-rmse:6.37699
# [114]	validation-rmse:6.37663
# [115]	validation-rmse:6.37641
# [116]	validation-rmse:6.37618
# [117]	validation-rmse:6.37561
# [118]	validation-rmse:6.37538
# [119]	validation-rmse:6.37463
# [120]	validation-rmse:6.37437
# [121]	validation-rmse:6.37410
# [122]	validation-rmse:6.37371
# [123]	validation-rmse:6.37320
# [124]	validation-rmse:6.37296
# [125]	validation-rmse:6.37257
# [126]	validation-rmse:6.37221
# [127]	validation-rmse:6.37157
# [128]	validation-rmse:6.37143
# [129]	validation-rmse:6.37118
# [130]	validation-rmse:6.37091
# [131]	validation-rmse:6.37052
# [132]	validation-rmse:6.37015
# [133]	validation-rmse:6.36994
# [134]	validation-rmse:6.36981
# [135]	validation-rmse:6.36946
# [136]	validation-rmse:6.36932
# [137]	validation-rmse:6.36906
# [138]	validation-rmse:6.36878
# [139]	validation-rmse:6.36832
# [140]	validation-rmse:6.36790
# [141]	validation-rmse:6.36768
# [142]	validation-rmse:6.36729
# [143]	validation-rmse:6.36716
# [144]	validation-rmse:6.36686
# [145]	validation-rmse:6.36666
# [146]	validation-rmse:6.36672
# [147]	validation-rmse:6.36644
# [148]	validation-rmse:6.36608
# [149]	validation-rmse:6.36598
# [150]	validation-rmse:6.36574
# [151]	validation-rmse:6.36519
# [152]	validation-rmse:6.36512
# [153]	validation-rmse:6.36459
# [154]	validation-rmse:6.36426
# [155]	validation-rmse:6.36397
# [156]	validation-rmse:6.36366
# [157]	validation-rmse:6.36354
# [158]	validation-rmse:6.36342
# [159]	validation-rmse:6.36280
# [160]	validation-rmse:6.36251
# [161]	validation-rmse:6.36185
# [162]	validation-rmse:6.36156
# [163]	validation-rmse:6.36114
# [164]	validation-rmse:6.36089
# [165]	validation-rmse:6.36054
# [166]	validation-rmse:6.36042
# [167]	validation-rmse:6.36017
# [168]	validation-rmse:6.35981
# [169]	validation-rmse:6.35975
# [170]	validation-rmse:6.35967
# [171]	validation-rmse:6.35921
# [172]	validation-rmse:6.35915
# [173]	validation-rmse:6.35913
# [174]	validation-rmse:6.35891
# [175]	validation-rmse:6.35849
# [176]	validation-rmse:6.35834
# [177]	validation-rmse:6.35829
# [178]	validation-rmse:6.35803
# [179]	validation-rmse:6.35741
# [180]	validation-rmse:6.35726
# [181]	validation-rmse:6.35710
# [182]	validation-rmse:6.35701
# [183]	validation-rmse:6.35704
# [184]	validation-rmse:6.35684
# [185]	validation-rmse:6.35673
# [186]	validation-rmse:6.35650
# [187]	validation-rmse:6.35615
# [188]	validation-rmse:6.35626
# [189]	validation-rmse:6.35638
# [190]	validation-rmse:6.35626
# [191]	validation-rmse:6.35606
# [192]	validation-rmse:6.35597
# [193]	validation-rmse:6.35587
# [194]	validation-rmse:6.35553
# [195]	validation-rmse:6.35560
# [196]	validation-rmse:6.35561
# [197]	validation-rmse:6.35576
# [198]	validation-rmse:6.35553
# [199]	validation-rmse:6.35520
# [200]	validation-rmse:6.35514
# [201]	validation-rmse:6.35521
# [202]	validation-rmse:6.35492
# [203]	validation-rmse:6.35469
# [204]	validation-rmse:6.35479
# [205]	validation-rmse:6.35402
# [206]	validation-rmse:6.35373
# [207]	validation-rmse:6.35361
# [208]	validation-rmse:6.35366
# [209]	validation-rmse:6.35358
# [210]	validation-rmse:6.35309
# [211]	validation-rmse:6.35264
# [212]	validation-rmse:6.35252
# [213]	validation-rmse:6.35241
# [214]	validation-rmse:6.35212
# [215]	validation-rmse:6.35203
# [216]	validation-rmse:6.35161
# [217]	validation-rmse:6.35154
# [218]	validation-rmse:6.35196
# [219]	validation-rmse:6.35212
# [220]	validation-rmse:6.35221
# [221]	validation-rmse:6.35215
# [222]	validation-rmse:6.35232
# [223]	validation-rmse:6.35225
# [224]	validation-rmse:6.35203
# [225]	validation-rmse:6.35171
# [226]	validation-rmse:6.35131
# [227]	validation-rmse:6.35118
# [228]	validation-rmse:6.35120
# [229]	validation-rmse:6.35119
# [230]	validation-rmse:6.35118
# [231]	validation-rmse:6.35108
# [232]	validation-rmse:6.35086
# [233]	validation-rmse:6.35097
# [234]	validation-rmse:6.35088
# [235]	validation-rmse:6.35062
# [236]	validation-rmse:6.35071
# [237]	validation-rmse:6.35085
# [238]	validation-rmse:6.35052
# [239]	validation-rmse:6.35033
# [240]	validation-rmse:6.35034
# [241]	validation-rmse:6.35026
# [242]	validation-rmse:6.35054
# [243]	validation-rmse:6.35040
# [244]	validation-rmse:6.35015
# [245]	validation-rmse:6.35000
# [246]	validation-rmse:6.34974
# [247]	validation-rmse:6.34962
# [248]	validation-rmse:6.34954
# [249]	validation-rmse:6.34965
# [250]	validation-rmse:6.34948
# [251]	validation-rmse:6.34953
# [252]	validation-rmse:6.34954
# [253]	validation-rmse:6.34943
# [254]	validation-rmse:6.34925
# [255]	validation-rmse:6.34911
# [256]	validation-rmse:6.34944
# [257]	validation-rmse:6.34951
# [258]	validation-rmse:6.35024
# [259]	validation-rmse:6.34990
# [260]	validation-rmse:6.34982
# [261]	validation-rmse:6.35027
# [262]	validation-rmse:6.35035
# [263]	validation-rmse:6.35021
# [264]	validation-rmse:6.34991
# [265]	validation-rmse:6.35002
# [266]	validation-rmse:6.34987
# [267]	validation-rmse:6.34976
# [268]	validation-rmse:6.34959
# [269]	validation-rmse:6.34955
# [270]	validation-rmse:6.34971
# [271]	validation-rmse:6.35005
# [272]	validation-rmse:6.34987
# [273]	validation-rmse:6.34946
# [274]	validation-rmse:6.34927
# [275]	validation-rmse:6.34923
# [276]	validation-rmse:6.34958
# [277]	validation-rmse:6.34950
# [278]	validation-rmse:6.34948
# [279]	validation-rmse:6.34924
# [280]	validation-rmse:6.34925
# [281]	validation-rmse:6.34905
# [282]	validation-rmse:6.34917
# [283]	validation-rmse:6.34926
# [284]	validation-rmse:6.34979
# [285]	validation-rmse:6.35025
# [286]	validation-rmse:6.35033
# [287]	validation-rmse:6.35013
# [288]	validation-rmse:6.35015
# [289]	validation-rmse:6.35011
# [290]	validation-rmse:6.34997
# [291]	validation-rmse:6.34995
# [292]	validation-rmse:6.34987
# [293]	validation-rmse:6.34965
# [294]	validation-rmse:6.34962
# [295]	validation-rmse:6.34933
# [296]	validation-rmse:6.34911
# [297]	validation-rmse:6.34908
# [298]	validation-rmse:6.34903
# [299]	validation-rmse:6.34897
# [300]	validation-rmse:6.34877
# [301]	validation-rmse:6.34860
# [302]	validation-rmse:6.34870
# [303]	validation-rmse:6.34844
# [304]	validation-rmse:6.34843
# [305]	validation-rmse:6.34920
# [306]	validation-rmse:6.34918
# [307]	validation-rmse:6.34965
# [308]	validation-rmse:6.34978
# [309]	validation-rmse:6.34989
# [310]	validation-rmse:6.35006
# [311]	validation-rmse:6.35012
# [312]	validation-rmse:6.35024
# [313]	validation-rmse:6.35017
# [314]	validation-rmse:6.34992
# [315]	validation-rmse:6.34971
# [316]	validation-rmse:6.34993
# [317]	validation-rmse:6.34991
# [318]	validation-rmse:6.35018
# [319]	validation-rmse:6.35005
# [320]	validation-rmse:6.35017
# [321]	validation-rmse:6.35012
# [322]	validation-rmse:6.35023
# [323]	validation-rmse:6.35023
# [324]	validation-rmse:6.35014
# [325]	validation-rmse:6.35008
# [326]	validation-rmse:6.34992
# [327]	validation-rmse:6.34984
# [328]	validation-rmse:6.34972
# [329]	validation-rmse:6.34963
# [330]	validation-rmse:6.34960
# [331]	validation-rmse:6.34948
# [332]	validation-rmse:6.34922
# [333]	validation-rmse:6.34933
# [334]	validation-rmse:6.34931
# [335]	validation-rmse:6.34945
# [336]	validation-rmse:6.34979
# [337]	validation-rmse:6.34970
# [338]	validation-rmse:6.34981
# [339]	validation-rmse:6.35067
# [340]	validation-rmse:6.35073
# [341]	validation-rmse:6.35088
# [342]	validation-rmse:6.35104
# [343]	validation-rmse:6.35126
# [344]	validation-rmse:6.35118
# [345]	validation-rmse:6.35126
# [346]	validation-rmse:6.35127
# [347]	validation-rmse:6.35129
# [348]	validation-rmse:6.35089
# [349]	validation-rmse:6.35080
# [350]	validation-rmse:6.35072
# [351]	validation-rmse:6.35034
# [352]	validation-rmse:6.35095
# [353]	validation-rmse:6.35109

# %% [markdown]
# ### MODEL SELECTION
#
# - RandomForestRegressor
# - GradientBoostingRegressor
# - ExtraTreeRegressor
# - LinearSVR

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

for model_class in (RandomForestRegressor,
                   GradientBoostingRegressor,
                   ExtraTreesRegressor,
                   LinearSVR):
    with mlflow.start_run(run_name="model_selection"):
        
        mlflow.sklearn.autolog()
        mlflow.set_tag("developer", "surawut")
        mlflow.set_tag("model", {model_class()})
        
        mlflow.log_param("train_path", {train_path})
        mlflow.log_param("valid_path", {valid_path})
        mlflow.log_artifact("./models/preprocessor.b", artifact_path='preprocessor')
        
        model = model_class()
        model.fit(X_train, y_train)
        
        y_pred = model.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
        
        with open('./models/preprocessor.b', 'wb') as dv_out:
            pickle.dump(dv, dv_out)
            
        mlflow.log_artifact('./models/preprocessor.b', artifact_path='preprocessor')

# %% [markdown]
# ## SELECTED THE BEST MODEL FROM MLFLOW AND EVALUATE MODEL

# %% [markdown]
# ## LOAD MODEL FOR PREDICTION

# %%
logged_model = 'runs:/c1db82cc4b45493a98c63bf0c8cc89e4/models_xgboost'

# %%
loaded_model = mlflow.pyfunc.load_model(logged_model)
loaded_model
# Out:
# [22:39:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_xgboost
#   flavor: mlflow.xgboost
#   run_id: c1db82cc4b45493a98c63bf0c8cc89e4

# %%
xgboost = mlflow.xgboost.load_model(logged_model)
xgboost
# Out:
# [22:39:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.

# %%
y_pred = xgboost.predict(valid)
y_pred[:10]
# Out:
# array([14.730225,  6.844986, 15.907544, 24.345303,  9.241478, 17.365046,
#        10.806662,  8.045458,  9.816886, 19.79216 ], dtype=float32)
